# %% [markdown]
# # Algorithmic Trading Model with ML4T Chapter 1 Processing Stooq Data Examples
# ### David Lowe
# ### July 4, 2022
#
# NOTE: This script is for learning purposes only and does not constitute a recommendation for buying or selling any stock mentioned in this script.
#
# SUMMARY: This project aims to construct and test an algorithmic trading model and document the end-to-end steps using a template.
#
# INTRODUCTION: This script aims to replicate the examples found in chapter one of the book Machine Learning for Algorithmic Trading by Stefan Jansen. The script seeks to validate further the Python environment and package requirements for running these code examples. The eventual goal is to integrate various example code segments into an end-to-end algorithmic trading system.
#
# This notebook contains information on downloading and processing equity information from Stooq.
#
# Dataset ML Model: Time series analysis with numerical attributes
#
# Dataset Used: Data services from Stooq
#
# Source and Further Discussion of the Code Examples: https://www.ml4trading.io/chapter/1

# %% [markdown]
# # Download and store STOOQ data

# %% [markdown]
# This notebook contains information on downloading the STOOQ stock and ETF price data that we use in [Chapter 09](../09_time_series_models) for a pairs trading strategy based on cointegration and [Chapter 11](../11_decision_trees_random_forests) for a long-short strategy using Random Forest return predictions.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
import requests
from io import BytesIO
from zipfile import ZipFile, BadZipFile

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from sklearn.datasets import fetch_openml

pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Set Data Store path

# %% [markdown]
# Modify the path to the `DATA_STORE` if you would like to store the data elsewhere and change the notebooks accordingly

# %%
DATA_STORE = Path('assets.h5')

# %% [markdown]
# ## Stooq Historical Market Data

# %% [markdown]
# > Note that the below downloading details may change at any time as Stooq updates their website; if you encounter errors, please inspect their website and raise a GitHub issue to let us know so we can update the information.
#
# > Update 12/2020: please note that STOOQ will disable automatic downloads and require CAPTCHA starting Dec 10, 2020 so that the code that downloads and unpacks the zip files will no longer work; please navigate to their website [here](https://stooq.com/db/h/) for manual download.

# %% [markdown]
# ### Download price data

# %% [markdown]
# 1. Download **price data** for the selected combination of asset class, market and frequency from [the Stooq website](https://stooq.com/db/h/)
# 2. Store the result under `stooq` using the preferred folder structure outlined on the website. It has the structure: `/data/freq/market/asset_class`, such as `/data/daily/us/nasdaq etfs`.

# %%
stooq_path = Path('stooq') 
if not stooq_path.exists():
    stooq_path.mkdir()

# %% [markdown]
# Use the symbol for the market you want to download price data for. In this book we'll be useing `us` and `jp`.
#
# Note: Stooq now requires some sort of Captcha to validate human interaction, the URL no longer works in the script.
# Instead, we will use the URL to download the files manually and process them via the script.

# %%
# STOOQ_URL = 'https://static.stooq.com/db/h/'

# %%
def download_price_data(market='us'):
    data_url = f'd_{market}_txt.zip'
    # response = requests.get(STOOQ_URL + data_url).content
    response = data_url
    # with ZipFile(BytesIO(response)) as zip_file:
    with ZipFile(response) as zip_file:
        for i, file in enumerate(zip_file.namelist()):
            if not file.endswith('.txt'):
                continue
            local_file = stooq_path / file
            local_file.parent.mkdir(parents=True, exist_ok=True)
            with local_file.open('wb') as output:
                for line in zip_file.open(file).readlines():
                    output.write(line)

# %%
for market in ['us', 'jp']:
    download_price_data(market=market)

# %% [markdown]
# ### Add symbols
#
# Note: Stooq now requires some sort of Captcha to validate human interaction, the URL no longer works in the script.
# Instead, we will use the URL to download the files manually and process them via the script.

# %% [markdown]
# Add the corresponding **symbols**, i.e., tickers and names by following the directory tree on the same site. You can also adapt the following code snippet using the appropriate asset code that you find by inspecting the url; this example works for NASDAQ ETFs that have code `g=69`:
# ```python
# df = pd.read_csv('https://stooq.com/db/l/?g=69', sep='        ').apply(lambda x: x.str.strip())
# df.columns = ['ticker', 'name']
# df.drop_duplicates('ticker').to_csv('stooq/data/tickers/us/nasdaq etfs.csv', index=False)
# ```

# %%
metadata_dict = {
    ('jp', 'tse etfs'): 34,
    ('jp', 'tse stocks'): 32,
    ('us', 'nasdaq etfs'): 69,
    ('us', 'nasdaq stocks'): 27,
    ('us', 'nyse etfs'): 70,
    ('us', 'nyse stocks'): 28,
    ('us', 'nysemkt stocks'): 26
}

# %%
for (market, asset_class), code in metadata_dict.items():
    print('Getting data for', market, 'and Asset Class', asset_class)
    # df = pd.read_csv(f'https://stooq.com/db/l/?g={code}', sep='        ').apply(lambda x: x.str.strip())
    df = pd.read_csv(f'stooq_data_{code}.txt', sep='        ').apply(lambda x: x.str.strip())
    df.columns = ['ticker', 'name']
    df = df.drop_duplicates('ticker').dropna()
    print(market, asset_class, f'# tickers: {df.shape[0]:,.0f}')
    path = stooq_path / 'tickers' / market
    if not path.exists():
        path.mkdir(parents=True)
    df.to_csv(path / f'{asset_class}.csv', index=False)
# Out:
# Getting data for jp and Asset Class tse etfs
# jp tse etfs # tickers: 363
# Getting data for jp and Asset Class tse stocks
# jp tse stocks # tickers: 3,834
# Getting data for us and Asset Class nasdaq etfs
# us nasdaq etfs # tickers: 392
# Getting data for us and Asset Class nasdaq stocks
# us nasdaq stocks # tickers: 5,357
# Getting data for us and Asset Class nyse etfs
# us nyse etfs # tickers: 2,427
# Getting data for us and Asset Class nyse stocks
# us nyse stocks # tickers: 3,240
# Getting data for us and Asset Class nysemkt stocks
# us nysemkt stocks # tickers: 300

# %% [markdown]
# ### Store price data in HDF5 format

# %% [markdown]
# To speed up loading, we store the price data in HDF format. The function `get_stooq_prices_and_symbols` loads data assuming the directory structure described above and takes the following arguments:
# - frequency (see Stooq website for options as these may change; default is `daily`
# - market (default: `us`), and
# - asset class (default: `nasdaq etfs`.
#
# It removes files that do not have data or do not appear in the corresponding list of symbols.

# %%
def get_stooq_prices_and_tickers(frequency='daily',
                                 market='us',
                                 asset_class='nasdaq etfs'):
    prices = []
    
    tickers = (pd.read_csv(stooq_path / 'tickers' / market / f'{asset_class}.csv'))

    if frequency in ['5 min', 'hourly']:
        parse_dates = [['date', 'time']]
        date_label = 'date_time'
    else:
        parse_dates = ['date']
        date_label = 'date'
    names = ['ticker', 'freq', 'date', 'time', 
             'open', 'high', 'low', 'close','volume', 'openint']
    
    usecols = ['ticker', 'open', 'high', 'low', 'close', 'volume'] + parse_dates
    path = stooq_path / 'data' / frequency / market / asset_class
    print(path.as_posix())
    files = path.glob('**/*.txt')
    for i, file in enumerate(files, 1):
        if i % 500 == 0:
            print(i)
        if file.stem not in set(tickers.ticker.str.lower()):
            print(file.stem, 'not available')
            file.unlink()
        else:
            try:
                df = (pd.read_csv(
                    file,
                    names=names,
                    usecols=usecols,
                    header=0,
                    parse_dates=parse_dates))
                prices.append(df)
            except pd.errors.EmptyDataError:
                print('\tdata missing', file.stem)
                file.unlink()

    prices = (pd.concat(prices, ignore_index=True)
              .rename(columns=str.lower)
              .set_index(['ticker', date_label])
              .apply(lambda x: pd.to_numeric(x, errors='coerce')))
    return prices, tickers

# %% [markdown]
# We'll be using US equities and ETFs in [Chapter 9](../09_time_series_models) and and Japanese equities in [Chapter 11](../11_decision_trees_random_forests). The following code collects the price data for the period 2000-2019 and stores it with the corresponding symbols in the global `assets.h5` store:

# %%
# load some Japanese and all US assets for 2000-2019
markets = {'jp': ['tse stocks'],
           'us': ['nasdaq etfs', 'nasdaq stocks', 'nyse etfs', 'nyse stocks', 'nysemkt stocks']
          }
frequency = 'daily'

idx = pd.IndexSlice
for market, asset_classes in markets.items():
    for asset_class in asset_classes:
        print(f'\n{asset_class}')
        prices, tickers = get_stooq_prices_and_tickers(frequency=frequency, 
                                                       market=market, 
                                                       asset_class=asset_class)
        
        prices = prices.sort_index().loc[idx[:, '2000': '2019'], :]
        names = prices.index.names
        prices = (prices
                  .reset_index()
                  .drop_duplicates()
                  .set_index(names)
                  .sort_index())
        
        print('\nNo. of observations per asset')
        print(prices.groupby('ticker').size().describe())
        key = f'stooq/{market}/{asset_class.replace(" ", "/")}/'
        
        print(prices.info(null_counts=True))
        
        prices.to_hdf(DATA_STORE, key + 'prices', format='t')
        
        print(tickers.info())
        tickers.to_hdf(DATA_STORE, key + 'tickers', format='t')
# Out:
# tse stocks
# stooq/data/daily/jp/tse stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
#
# No. of observations per asset
# count    3521.000000
# mean     2816.637887
# std      1172.520895
# min         1.000000
# 25%      2178.000000
# 50%      3041.000000
# 75%      3621.000000
# max      4905.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9917382 entries, ('1301.JP', Timestamp('2005-03-22 00:00:00')) to ('9997.JP', Timestamp('2019-12-30 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    9917382 non-null  float64
#  1   high    9917382 non-null  float64
#  2   low     9917382 non-null  float64
#  3   close   9917382 non-null  float64
#  4   volume  9917382 non-null  float64
# dtypes: float64(5)
# memory usage: 416.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3834 entries, 0 to 3833
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3834 non-null   object
#  1   name    3834 non-null   object
# dtypes: object(2)
# memory usage: 60.0+ KB
# None
#
# nasdaq etfs
# stooq/data/daily/us/nasdaq etfs
#
# No. of observations per asset
# count     348.000000
# mean     1611.686782
# std      1134.435249
# min         2.000000
# 25%       560.750000
# 50%      1441.000000
# 75%      2390.000000
# max      5031.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 560867 entries, ('AADR.US', Timestamp('2010-07-21 00:00:00')) to ('YLDE.US', Timestamp('2019-12-27 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    560867 non-null  float64
#  1   high    560867 non-null  float64
#  2   low     560867 non-null  float64
#  3   close   560867 non-null  float64
#  4   volume  560867 non-null  float64
# dtypes: float64(5)
# memory usage: 23.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  392 non-null    object
#  1   name    392 non-null    object
# dtypes: object(2)
# memory usage: 6.2+ KB
# None
#
# nasdaq stocks
# stooq/data/daily/us/nasdaq stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# tydev.us not available
# 5000
#
# No. of observations per asset
# count    2562.000000
# mean     2173.875878
# std      1510.889547
# min         1.000000
# 25%       629.250000
# 50%      2054.500000
# 75%      3736.000000
# max      5031.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5569470 entries, ('AACG.US', Timestamp('2008-01-28 00:00:00')) to ('ZYXI.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    5569470 non-null  float64
#  1   high    5569470 non-null  float64
#  2   low     5569470 non-null  float64
#  3   close   5569470 non-null  float64
#  4   volume  5569470 non-null  float64
# dtypes: float64(5)
# memory usage: 234.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5357 entries, 0 to 5356
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  5357 non-null   object
#  1   name    5357 non-null   object
# dtypes: object(2)
# memory usage: 83.8+ KB
# None
#
# nyse etfs
# stooq/data/daily/us/nyse etfs
# arvr.us not available
# 500
# 1000
# 1500
# rbin.us not available
# 2000
#
# No. of observations per asset
# count    1649.000000
# mean     1711.767132
# std      1260.630846
# min         1.000000
# 25%       516.000000
# 50%      1529.000000
# 75%      2981.000000
# max      3738.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2822704 entries, ('AAAU.US', Timestamp('2018-08-15 00:00:00')) to ('ZSL.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    2822704 non-null  float64
#  1   high    2822704 non-null  float64
#  2   low     2822704 non-null  float64
#  3   close   2822704 non-null  float64
#  4   volume  2822704 non-null  float64
# dtypes: float64(5)
# memory usage: 118.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2427 entries, 0 to 2426
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  2427 non-null   object
#  1   name    2427 non-null   object
# dtypes: object(2)
# memory usage: 38.0+ KB
# None
#
# nyse stocks
# stooq/data/daily/us/nyse stocks
# aac-ws.us not available
# aaic_b.us not available
# aaic_c.us not available
# aaqc-u.us not available
# aaqc-ws.us not available
# acaq-u.us not available
# acaq-ws.us not available
# acdi-u.us not available
# acdi-ws.us not available
# achr-ws.us not available
# acii-u.us not available
# acii-ws.us not available
# acro-u.us not available
# acro-ws.us not available
# adex-u.us not available
# adex-ws.us not available
# aeva-ws.us not available
# aftr-u.us not available
# aftr-ws.us not available
# agac-u.us not available
# agac-ws.us not available
# alin_a.us not available
# alin_b.us not available
# alin_e.us not available
# allg-ws.us not available
# altg_a.us not available
# ambc-ws.us not available
# ambp-ws.us not available
# ampi-u.us not available
# ampi-ws.us not available
# amps-ws.us not available
# anac-u.us not available
# anac-ws.us not available
# apca-u.us not available
# apca-ws.us not available
# apgb-u.us not available
# apgb-ws.us not available
# apn-ws.us not available
# apsg-u.us not available
# aptv_a.us not available
# argo_a.us not available
# asaq-u.us not available
# asaq-ws.us not available
# asz-ws.us not available
# ata-ws.us not available
# ataq-u.us not available
# ataq-ws.us not available
# atco_d.us not available
# atco_h.us not available
# atco_i.us not available
# atek-u.us not available
# atek-ws.us not available
# atip-ws.us not available
# aus-ws.us not available
# avan-u.us not available
# avan-ws.us not available
# avtr_a.us not available
# axac-r.us not available
# axac-ws.us not available
# axh-ws.us not available
# baca-u.us not available
# baca-ws.us not available
# bark-ws.us not available
# bbai-ws.us not available
# bbln-ws.us not available
# bfac-u.us not available
# bfac-ws.us not available
# bfly-ws.us not available
# bgsx-u.us not available
# bgsx-ws.us not available
# bhil-ws.us not available
# bite-u.us not available
# bite-ws.us not available
# bkkt-ws.us not available
# 500
# bksy-ws.us not available
# blua-u.us not available
# blua-ws.us not available
# bmac-u.us not available
# bmac-ws.us not available
# boac-u.us not available
# boac-ws.us not available
# boas-u.us not available
# boas-ws.us not available
# body-ws.us not available
# bowl-ws.us not available
# boxd-ws.us not available
# brd-ws.us not available
# brds-ws.us not available
# bsaq-u.us not available
# bsaq-ws.us not available
# byn-ws.us not available
# cade_a.us not available
# cano-ws.us not available
# cas-ws.us not available
# ccv-ws.us not available
# ccvi-u.us not available
# ccvi-ws.us not available
# celg-r.us not available
# chaa-u.us not available
# chaa-ws.us not available
# chmi_a.us not available
# chmi_b.us not available
# claa-u.us not available
# claa-ws.us not available
# clas-u.us not available
# clas-ws.us not available
# clbr-u.us not available
# clbr-ws.us not available
# cldt_a.us not available
# clim-u.us not available
# clim-ws.us not available
# clvt_a.us not available
# cmre_b.us not available
# cmre_c.us not available
# cmre_d.us not available
# cmre_e.us not available
# cnd-ws.us not available
# cnda-u.us not available
# cnda-ws.us not available
# cndb-u.us not available
# cndb-ws.us not available
# codi_a.us not available
# codi_b.us not available
# codi_c.us not available
# corr_a.us not available
# cors-ws.us not available
# cptk-u.us not available
# cptk-ws.us not available
# cpuh-u.us not available
# cpuh-ws.us not available
# crhc-u.us not available
# crhc-ws.us not available
# cru-ws.us not available
# csta-u.us not available
# csta-ws.us not available
# ctos-ws.us not available
# ctv-ws.us not available
# cubi_e.us not available
# cubi_f.us not available
# cve-ws.us not available
# cvii-u.us not available
# cvii-ws.us not available
# cwen-a.us not available
# cxac-u.us not available
# cxac-ws.us not available
# czoo-ws.us not available
# dbrg_h.us not available
# dbrg_i.us not available
# dbrg_j.us not available
# 1000
# dlng_a.us not available
# dlng_b.us not available
# dms-ws.us not available
# dmys-u.us not available
# dmys-ws.us not available
# dna-ws.us not available
# dnz-ws.us not available
# doma-ws.us not available
# dsaq-u.us not available
# dsaq-ws.us not available
# dwin-u.us not available
# dwin-ws.us not available
# eggf-u.us not available
# eggf-ws.us not available
# ehab-w.us not available
# enpc-u.us not available
# enpc-ws.us not available
# eocw-u.us not available
# eocw-ws.us not available
# epwr-u.us not available
# epwr-ws.us not available
# eqd-ws.us not available
# eqha-u.us not available
# eqha-ws.us not available
# esm-ws.us not available
# etwo-ws.us not available
# eve-ws.us not available
# evex-ws.us not available
# evtl-ws.us not available
# faca-u.us not available
# faca-ws.us not available
# fact-u.us not available
# fact-ws.us not available
# fath-ws.us not available
# fbrt_e.us not available
# fcax-u.us not available
# fcax-ws.us not available
# flag-u.us not available
# flag-ws.us not available
# flme-u.us not available
# flme-ws.us not available
# flya-u.us not available
# flya-ws.us not available
# foa-ws.us not available
# fpac-u.us not available
# fpac-ws.us not available
# frey-ws.us not available
# frge-ws.us not available
# frxb-u.us not available
# frxb-ws.us not available
# fsnb-u.us not available
# fsnb-ws.us not available
# fst-ws.us not available
# ftai_c.us not available
# ftev-u.us not available
# ftev-ws.us not available
# fviv-u.us not available
# fviv-ws.us not available
# fvt-ws.us not available
# fzt-ws.us not available
# gapa-u.us not available
# gapa-ws.us not available
# gaq-ws.us not available
# gbtg-ws.us not available
# geni-ws.us not available
# gfor-u.us not available
# gfor-ws.us not available
# gfx-ws.us not available
# 1500
# gia-ws.us not available
# glog_a.us not available
# glop_a.us not available
# glop_b.us not available
# glop_c.us not available
# gls-ws.us not available
# gmre_a.us not available
# goac-u.us not available
# goac-ws.us not available
# gogn-u.us not available
# gogn-ws.us not available
# gpmt_a.us not available
# grbk_a.us not available
# grov-ws.us not available
# gsqb-u.us not available
# gsqb-ws.us not available
# gsqd-u.us not available
# gsqd-ws.us not available
# gutr-w.us not available
# gwh-ws.us not available
# hfro_a.us not available
# hgty-ws.us not available
# hhla-u.us not available
# hhla-ws.us not available
# higa-u.us not available
# higa-ws.us not available
# hipo-ws.us not available
# hixr-w.us not available
# hlgn-ws.us not available
# hlly-ws.us not available
# hma-ws.us not available
# hmlp_a.us not available
# hpx-ws.us not available
# htaq-u.us not available
# htaq-ws.us not available
# htpa-u.us not available
# htpa-ws.us not available
# hugs-u.us not available
# hugs-ws.us not available
# hwkz-u.us not available
# hwkz-ws.us not available
# hzon-u.us not available
# hzon-ws.us not available
# iber-u.us not available
# iber-ws.us not available
# icnc-u.us not available
# icnc-ws.us not available
# ifin-ws.us not available
# iipr_a.us not available
# impx-u.us not available
# impx-ws.us not available
# inaq-u.us not available
# inaq-ws.us not available
# insw_a.us not available
# ionq-ws.us not available
# ipod-u.us not available
# ipod-ws.us not available
# ipof-u.us not available
# ipof-ws.us not available
# ipva-u.us not available
# ipva-ws.us not available
# ipvf-u.us not available
# ipvf-ws.us not available
# irnt-ws.us not available
# irrx-u.us not available
# irrx-ws.us not available
# irs-ws.us not available
# jatt-u.us not available
# jatt-ws.us not available
# joby-ws.us not available
# jun-ws.us not available
# jwsm-u.us not available
# jwsm-ws.us not available
# kahc-u.us not available
# kahc-ws.us not available
# kcac-u.us not available
# kcac-ws-a.us not available
# kcac-ws.us not available
# kcgi-u.us not available
# kcgi-ws.us not available
# knsw-u.us not available
# knsw-ws.us not available
# kore-ws.us not available
# 2000
# kref_a.us not available
# kwac-u.us not available
# kwac-ws.us not available
# lcw-ws.us not available
# leap-u.us not available
# leap-ws.us not available
# lev-ws.us not available
# lgv-ws.us not available
# lhc-ws.us not available
# llap-ws.us not available
# lnfa-u.us not available
# lnfa-ws.us not available
# locc-u.us not available
# locc-ws.us not available
# locl-ws.us not available
# lokm-u.us not available
# lokm-ws.us not available
# macc-u.us not available
# macc-ws.us not available
# mbac-u.us not available
# mbac-ws.us not available
# mbsc-u.us not available
# mbsc-ws.us not available
# mdh-ws.us not available
# mir-ws.us not available
# mit-ws.us not available
# mitt_a.us not available
# mitt_b.us not available
# mitt_c.us not available
# mkfg-ws.us not available
# mntn-u.us not available
# mntn-ws.us not available
# motv-u.us not available
# mpln-ws.us not available
# mtal-u.us not available
# mtal-ws.us not available
# mtvc-u.us not available
# mtvc-ws.us not available
# netc-u.us not available
# netc-ws.us not available
# nfnt-u.us not available
# nfnt-ws.us not available
# nfys-u.us not available
# nfys-ws.us not available
# ngc-ws.us not available
# nrdy-ws.us not available
# nref_a.us not available
# nrgv-ws.us not available
# nstb-u.us not available
# nstb-ws.us not available
# nstc-u.us not available
# nstc-ws.us not available
# nstd-u.us not available
# nstd-ws.us not available
# nuvb-ws.us not available
# 2500
# nxdt_a.us not available
# nycb_a.us not available
# nycb_u.us not available
# oacb-u.us not available
# oacb-ws.us not available
# oca-ws.us not available
# opa-ws.us not available
# opad-ws.us not available
# opfi-ws.us not available
# osi-ws.us not available
# oust-ws.us not available
# owl-ws.us not available
# owlt-ws.us not available
# oxy-ws.us not available
# paci-u.us not available
# paci-ws.us not available
# pcpc-u.us not available
# pcpc-ws.us not available
# pdot-u.us not available
# pdot-ws.us not available
# pgss-u.us not available
# pgss-ws.us not available
# phyt-u.us not available
# phyt-ws.us not available
# piai-u.us not available
# piai-ws.us not available
# picc-u.us not available
# picc-ws.us not available
# pipp-u.us not available
# pipp-ws.us not available
# pmvc-u.us not available
# pmvc-ws.us not available
# pntm-u.us not available
# pntm-ws.us not available
# pond-u.us not available
# pond-ws.us not available
# port-u.us not available
# port-ws.us not available
# prbm-u.us not available
# prbm-ws.us not available
# prif_d.us not available
# prif_f.us not available
# prif_g.us not available
# prif_h.us not available
# prif_i.us not available
# prif_j.us not available
# prif_k.us not available
# prif_l.us not available
# prpb-u.us not available
# prpb-ws.us not available
# prpc-u.us not available
# prpc-ws.us not available
# psec_a.us not available
# psfe-ws.us not available
# pspc-u.us not available
# pspc-ws.us not available
# psth-ws.us not available
# qfta-u.us not available
# qfta-ws.us not available
# qngy-ws.us not available
# rbac-u.us not available
# rbac-ws.us not available
# rbot-ws.us not available
# rcfa-u.us not available
# rcfa-ws.us not available
# rdw-ws.us not available
# rexr_b.us not available
# rexr_c.us not available
# rjac-u.us not available
# rjac-ws.us not available
# rkly-ws.us not available
# rkta-u.us not available
# rkta-ws.us not available
# roni-u.us not available
# roni-ws.us not available
# ross-u.us not available
# ross-ws.us not available
# rrac-u.us not available
# rrac-ws.us not available
# 3000
# sbii-u.us not available
# sbii-ws.us not available
# schw_d.us not available
# schw_j.us not available
# scua-u.us not available
# scua-ws.us not available
# seal_a.us not available
# seal_b.us not available
# seda-u.us not available
# seda-ws.us not available
# ses-ws.us not available
# sghc-ws.us not available
# shap-u.us not available
# shap-ws.us not available
# shpw-ws.us not available
# sitc_a.us not available
# skil-ws.us not available
# slac-u.us not available
# slac-ws.us not available
# smr-ws.us not available
# spgs-u.us not available
# spgs-ws.us not available
# spir-ws.us not available
# splp_a.us not available
# spnt_b.us not available
# sst-ws.us not available
# ssu-ws.us not available
# star_d.us not available
# star_g.us not available
# star_i.us not available
# stet-u.us not available
# stet-ws.us not available
# stre-u.us not available
# stre-ws.us not available
# stry-ws.us not available
# suac-u.us not available
# suac-ws.us not available
# sunl-ws.us not available
# taca-u.us not available
# taca-ws.us not available
# tcoa-u.us not available
# tcoa-ws.us not available
# tdw-ws-a.us not available
# tdw-ws-b.us not available
# tgr-ws.us not available
# tinv-u.us not available
# tinv-ws.us not available
# tlga-u.us not available
# tlga-ws.us not available
# tmac-u.us not available
# tmac-ws.us not available
# tpgy-u.us not available
# tpgy-ws.us not available
# traq-u.us not available
# traq-ws.us not available
# trca-u.us not available
# trca-ws.us not available
# tris-u.us not available
# tris-ws.us not available
# trtl-u.us not available
# trtl-ws.us not available
# trtn_a.us not available
# trtn_b.us not available
# trtn_c.us not available
# trtn_d.us not available
# trtn_e.us not available
# trtx_c.us not available
# tspq-u.us not available
# tspq-ws.us not available
# twnd-u.us not available
# twnd-ws.us not available
# twni-u.us not available
# twni-ws.us not available
# uph-ws.us not available
# 3500
# uwmc-ws.us not available
# val-ws.us not available
# vcxb-u.us not available
# vcxb-ws.us not available
# vgii-u.us not available
# vgii-ws.us not available
# vln-ws.us not available
# vlta-ws.us not available
# voya_b.us not available
# vst-ws-a.us not available
# vygg-u.us not available
# vygg-ws.us not available
# warr-u.us not available
# warr-ws.us not available
# wavc-u.us not available
# wavc-ws.us not available
# wbx-ws.us not available
# wel-ws.us not available
# wnnr-u.us not available
# wnnr-ws.us not available
# wpca-u.us not available
# wpca-ws.us not available
# wpcb-u.us not available
# wpcb-ws.us not available
# wqga-u.us not available
# wqga-ws.us not available
# wrac-u.us not available
# wrac-ws.us not available
# xflt_a.us not available
# xpoa-u.us not available
# xpoa-ws.us not available
# zev-ws.us not available
# zgn-ws.us not available
#
# No. of observations per asset
# count    2401.000000
# mean     2682.786339
# std      1514.978205
# min         2.000000
# 25%      1316.000000
# 50%      3573.000000
# 75%      3737.000000
# max      5031.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6441370 entries, ('A.US', Timestamp('2000-01-03 00:00:00')) to ('ZYME.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    6441370 non-null  float64
#  1   high    6441370 non-null  float64
#  2   low     6441370 non-null  float64
#  3   close   6441370 non-null  float64
#  4   volume  6441370 non-null  float64
# dtypes: float64(5)
# memory usage: 270.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240 entries, 0 to 3239
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3240 non-null   object
#  1   name    3240 non-null   object
# dtypes: object(2)
# memory usage: 50.8+ KB
# None
#
# nysemkt stocks
# stooq/data/daily/us/nysemkt stocks
# adra-u.us not available
# adra-ws.us not available
# adrt-u.us not available
# adrt-ws.us not available
# bmtx-ws.us not available
# brmk-ws.us not available
# glta-u.us not available
# glta-ws.us not available
# glur-w.us not available
# goed-ws.us not available
# groy-ws.us not available
# hnra-ws.us not available
# klr-ws.us not available
# lgl-ws.us not available
# mimo-ws.us not available
# nhsr-w.us not available
# nile_d.us not available
# phge-ws.us not available
# plym_a.us not available
# rcor-ws.us not available
# sach_a.us not available
# sbev-ws.us not available
# skyh-ws.us not available
# str-ws.us not available
# tdw-ws.us not available
# vhaq-r.us not available
# vhaq-u.us not available
# vhaq-ws.us not available
# ycbd_a.us not available
#
# No. of observations per asset
# count     243.000000
# mean     2658.452675
# std      1283.446281
# min         4.000000
# 25%      1583.000000
# 50%      3356.000000
# 75%      3728.500000
# max      5029.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 646004 entries, ('AAU.US', Timestamp('2005-02-25 00:00:00')) to ('ZOM.US', Timestamp('2019-12-31 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    646004 non-null  float64
#  1   high    646004 non-null  float64
#  2   low     646004 non-null  float64
#  3   close   646004 non-null  float64
#  4   volume  646004 non-null  float64
# dtypes: float64(5)
# memory usage: 27.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  300 non-null    object
#  1   name    300 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB
# None
