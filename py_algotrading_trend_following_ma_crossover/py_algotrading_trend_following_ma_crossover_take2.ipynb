# %% [markdown]
# # Algorithmic Trading Model for Trend-Following with Moving Averages Crossover Strategy Using Python Take 2
# ### David Lowe
# ### February 26, 2021
#
# NOTE: This script is for learning purposes only and does not constitute a recommendation for buying or selling any stock mentioned in this script.
#
# SUMMARY: This project aims to construct and test an algorithmic trading model and document the end-to-end steps using a template.
#
# INTRODUCTION: This algorithmic trading model examines a simple trend-following strategy for a stock. The model enters a position when the price reaches either the highest or the lowest points for the last X number of days. The model will exit the trade when the stock's fast and slow moving-average lines cross each other.
#
# In addition to the stock price, the models will also use the trading volume indicator to confirm the buy/sell signal further. Finally, the strategy will also incorporate a fixed holding window. The system will exit the position when the holding window reaches the maximum window size.
#
# From iteration Take1, we set up the models using a trend window size for long trades only. The window size varied from 10 to 50 trading days at a 5-day increment. We used 20 to 40 days for the fast-moving average and 50 to 80 days for the slow-moving average. The models also incorporated a volume indicator with a fixed window size of 10 days to confirm the buy/sell signal. Furthermore, we did not limit the holding period by setting the maximum holding period to 999 days for this iteration.
#
# In this Take2 iteration, we will set up the models using a trend window size for short trades only. The window size will vary from 10 to 50 trading days at a 5-day increment. We will use 20 to 40 days for the fast-moving average and 50 to 80 days for the slow-moving average. The models will also incorporate a volume indicator with a fixed window size of 10 days to confirm the buy/sell signal. Furthermore, we will not limit the holding period by setting the maximum holding period to 999 days for this iteration.
#
# ANALYSIS: From iteration Take1, we analyzed the stock prices for Apple Inc. (AAPL) between January 1, 2018, and February 19, 2021. The top trading model produced a profit of 92.77 dollars per share. The buy-and-hold approach yielded a gain of 87.70 dollars per share.
#
# In this Take2 iteration, we analyzed the stock prices for Apple Inc. (AAPL) between January 1, 2018, and February 19, 2021. The top trading model produced a loss of 3.57 dollars per share. The buy-and-hold approach yielded a gain of 87.70 dollars per share.
#
# CONCLUSION: For the stock of AAPL during the modeling time frame, the short-only trading strategy produced a much worse return than the buy-and-hold approach. However, we should consider modeling this stock further by experimenting with more variations of the strategy.
#
# Dataset ML Model: Time series analysis with numerical attributes
#
# Dataset Used: Quandl
#
# An algorithmic trading modeling project generally can be broken down into about five major tasks:
#
# 1. Prepare Environment
# 2. Acquire and Pre-Process Data
# 3. Implement and Train Models
# 4. Back-test Models
# 5. Evaluate Strategy Performance

# %% [markdown]
# ## Task 1 - Prepare Environment

# %%
# # Install the necessary packages for Colab
# !pip install python-dotenv PyMySQL

# %%
# # Retrieve the GPU information from Colab
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#     print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
#     print('and then re-execute this cell.')
# else:
#     print(gpu_info)

# %%
# # Retrieve the memory configuration from Colab
# from psutil import virtual_memory
# ram_gb = virtual_memory().total / 1e9
# print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
#
# if ram_gb < 20:
#     print('To enable a high-RAM runtime, select the Runtime → "Change runtime type"')
#     print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
#     print('re-execute this cell.')
# else:
#     print('You are using a high-RAM runtime!')

# %%
# # Retrieve the CPU information
# ncpu = !nproc
# print("The number of available CPUs is:", ncpu[0])

# %% [markdown]
# ### 1.a) Load libraries and modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
from datetime import date, datetime, timedelta
import requests
import json
from dotenv import load_dotenv
# import pandas_datareader.data as pdr

# Begin the timer for the script processing
startTimeScript = datetime.now()

# %% [markdown]
# ### 1.b) Set up the controlling parameters and functions¶

# %%
# Specify the key modeling parameters below
STOCK_SYMBOL = 'AAPL'
INITIAL_CAPITAL = 0

# Specify the moving average parameters for the trading strategy
WINDOW_MIN = 10
WINDOW_MAX = 50
WINDOW_INCREMENT = 10
VOL_MA_MIN = 10
VOL_MA_MAX = 10
VOL_MA_INCREMENT = 10
HOLDING_MIN = 999
HOLDING_MAX = 999
HOLDING_INCREMENT = 10
FAST_MA_MIN = 20
FAST_MA_MAX = 40
SLOW_MA_MIN = 50
SLOW_MA_MAX = 100
MA_INCREMENT = 10
MA_GAP = 10

LONG_ONLY = False
SHORT_ONLY = True
if LONG_ONLY and SHORT_ONLY: sys.exit("Cannot have both LONG_ONLY and SHORT_LONG flags be set to True. Script Processing Aborted!!!")

# The number of extra days of data we need for calculating moving averages (usually equals to the largest value of slow MA)
EXTRA_DAYS = SLOW_MA_MAX

MODEL_START_DATE = date(2018, 1, 1)
print("Starting date for the model:", MODEL_START_DATE)

# MODEL_END_DATE = datetime.now().date()
MODEL_END_DATE = date(2021, 2, 19)
print("Ending date for the model:", MODEL_END_DATE)

# data_start_date = MODEL_START_DATE
data_start_date = MODEL_START_DATE - timedelta(days=int(EXTRA_DAYS * 1.5)) # Need more pricing data to calculate moving averages
print("First date of data we need for modeling:", data_start_date)

data_end_date = MODEL_END_DATE
print("Last date of data we need for modeling:", data_end_date)
# Out:
# Starting date for the model: 2018-01-01
# Ending date for the model: 2021-02-19
# First date of data we need for modeling: 2017-08-04
# Last date of data we need for modeling: 2021-02-19

# %%
# Specify the script running parameters below

# Set Pandas options
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 255)

# Configure the plotting style
plt.style.use('seaborn')

# Set up the verbose flag to print detailed messages for debugging (setting True will activate!)
verbose_signals = False
verbose_models = False
verbose_graphs = False
verbose_trade_actions = False
verbose_portfolios = False
verbose_transactions = True
verbose_positions = True

# %%
# Set up the parent directory location for loading the dotenv files

# Mount Google Drive locally for storing files
# from google.colab import drive
# drive.mount('/content/gdrive')
# gdrivePrefix = '/content/gdrive/My Drive/Colab_Downloads/'
# env_path = '/content/gdrive/My Drive/Colab Notebooks/'
# dotenv_path = env_path + "python_script.env"
# load_dotenv(dotenv_path=dotenv_path)

# Set up access to the dotenv file on local PC
# env_path = "/Users/david/PycharmProjects/"
# dotenv_path = env_path + "python_script.env"
# load_dotenv(dotenv_path=dotenv_path)

# %% [markdown]
# ## Task 2 - Acquire and Pre-Process Data

# %%
# Set up the data service provider and data acquisition parameters
data_service = 'Quandl'

# Check and see whether the API key is available
api_key = os.environ.get('QUANDL_API')
if api_key is None: sys.exit("API key for Quandl not available. Script Processing Aborted!!!")

start_date_string = data_start_date.strftime('%Y-%m-%d')
end_date_string = data_end_date.strftime('%Y-%m-%d')
api_url = "https://www.quandl.com/api/v3/datatables/SHARADAR/SEP.json?date.gte=%s&date.lte=%s&ticker=%s&api_key=%s" % (start_date_string, end_date_string, STOCK_SYMBOL, api_key)
response = requests.get(api_url)
resp_dict = json.loads(response.text)
stock_rawdata = pd.DataFrame(resp_dict['datatable']['data'])
print(len(stock_rawdata), 'data points retrieved from the API call.')
# Out:
# 892 data points retrieved from the API call.

# %%
stock_rawdata.columns = ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'dividend', 'closeunadj', 'lastupdated']
# stock_rawdata.set_index('date', inplace=True)
stock_rawdata.index = pd.to_datetime(stock_rawdata.date)
stock_pricing = stock_rawdata.sort_index(ascending=True)
print(stock_pricing.head())
print()
print(stock_pricing.tail())
# Out:
#            ticker        date    open    high     low   close       volume  dividend  closeunadj lastupdated
# date
# 2017-08-04   AAPL  2017-08-04  39.017  39.350  38.922  39.097   82239408.0     0.000      156.39  2020-08-31
# 2017-08-07   AAPL  2017-08-07  39.265  39.730  39.167  39.703   87481284.0     0.000      158.81  2020-08-31
# 2017-08-08   AAPL  2017-08-08  39.650  40.458  39.568  40.020  144823584.0     0.000      160.08  2020-08-31
# 2017-08-09   AAPL  2017-08-09  39.815  40.318  39.778  40.265  104526120.0     0.000      161.06  2020-08-31
# 2017-08-10   AAPL  2017-08-10  39.975  40.000  38.657  38.830  163217092.0     0.158      155.32  2020-08-31
#
#            ticker        date    open     high      low   close      volume  dividend  closeunadj lastupdated
# date
# 2021-02-12   AAPL  2021-02-12  134.35  135.530  133.692  135.37  59803219.0       0.0      135.37  2021-02-12
# 2021-02-16   AAPL  2021-02-16  135.49  136.010  132.790  133.19  80576316.0       0.0      133.19  2021-02-16
# 2021-02-17   AAPL  2021-02-17  131.25  132.220  129.470  130.84  98085249.0       0.0      130.84  2021-02-17
# 2021-02-18   AAPL  2021-02-18  129.20  129.995  127.410  129.71  96856748.0       0.0      129.71  2021-02-18
# 2021-02-19   AAPL  2021-02-19  130.24  130.710  128.800  129.87  87668834.0       0.0      129.87  2021-02-19

# %%
# Set up the standard column name for modeling
# Column names may be data-provider specific!
MODEL_TEMPLATE = stock_pricing.loc[:, ['open','close','volume']]
MODEL_TEMPLATE.rename(columns={'open': 'open_price', 'close': 'close_price', 'volume': 'trading_volume'}, inplace=True)
plot_title = 'Historical Stock Close Price for ' + STOCK_SYMBOL + ' from ' + data_service
MODEL_TEMPLATE['close_price'].plot(figsize=(16,9), title=plot_title)
plt.show()

# %% [markdown]
# ## Task 3 - Implement and Train Models

# %%
# Define the function that will generate the indicators and trading signals
# General logic for processing the trading signals for each time period
# 1 - Check to see whether we need to execute a trading action from the previous day's signal. Once the trading action is executed, move on to the next day.
# 2 - If no trade actions to execute on open, check to see whether we have any breakout that generates a trading signal. If we have a new trading signal and currently has no position, mark the entry action for the next day.
# 3 - If no new signal for today, check to see whether we need to exit any existing position. If we have an exit signal and currently hold a position, mark the exit action for the next day.
# 4 - If nothing is going on, mark up the trading model appropriately and move to the next day.

def populate_signals(window=WINDOW_MIN, vol_ma=VOL_MA_MIN, max_holding=HOLDING_MAX, fast_ma=FAST_MA_MIN, slow_ma=SLOW_MA_MIN):

    trade_model = MODEL_TEMPLATE.copy()
    trade_model['window_high'] = trade_model['close_price'].shift(1).rolling(window=window).max()
    trade_model['window_low'] = trade_model['close_price'].shift(1).rolling(window=window).min()
    trade_model['window_avg'] = trade_model['close_price'].shift(1).rolling(window=window).mean()
    trade_model['volume_ma'] = trade_model['trading_volume'].rolling(vol_ma).mean()
    trade_model['fast_ma'] = trade_model['close_price'].rolling(fast_ma).mean()
    trade_model['slow_ma'] = trade_model['close_price'].rolling(slow_ma).mean()
    trade_model['ma_change'] = trade_model['fast_ma'] - trade_model['slow_ma']
    trade_model['holding_period'] = 0
    trade_model['buy_on_open'] = False
    trade_model['sell_on_open'] = False
    trade_model['short_on_open'] = False
    trade_model['cover_on_open'] = False
    trade_model['position_long'] = False
    trade_model['position_short'] = False
    trade_model['close_above_avg'] = False  # Price closes above the window average
    trade_model['close_below_avg'] = False  # Price closes below the window average

    # Truncate the model to the required starting and ending dates
    trade_model = trade_model[MODEL_START_DATE:MODEL_END_DATE]
    last_index = len(trade_model) - 1

    for k in range(len(trade_model)):
        breakout_high = trade_model.at[trade_model.index[k],'close_price'] - trade_model.at[trade_model.index[k],'window_high']
        breakout_low = trade_model.at[trade_model.index[k],'close_price'] - trade_model.at[trade_model.index[k],'window_low']
        # crossover_avg = trade_model.at[trade_model.index[k],'close_price'] - trade_model.at[trade_model.index[k],'window_avg']
        trade_volume = trade_model.at[trade_model.index[k],'trading_volume']
        average_volume = trade_model.at[trade_model.index[k],'volume_ma']
        if k == 0:
            currently_long = False
            currently_short = False
        else:
            currently_long = trade_model.at[trade_model.index[k-1],'position_long']
            currently_short = trade_model.at[trade_model.index[k-1],'position_short']

        holding_period = trade_model.at[trade_model.index[k-1],'holding_period']
        if trade_model.at[trade_model.index[k-1],'position_long'] or trade_model.at[trade_model.index[k-1],'position_short']:
            holding_period = holding_period + 1
            trade_model.at[trade_model.index[k],'holding_period'] = holding_period

        # Check to see whether we need to execute any trade action on open
        if trade_model.at[trade_model.index[k],'buy_on_open']:
            trade_model.at[trade_model.index[k],'position_long'] = True
        elif trade_model.at[trade_model.index[k],'short_on_open']:
            trade_model.at[trade_model.index[k],'position_short'] = True
        elif trade_model.at[trade_model.index[k],'sell_on_open']:
            trade_model.at[trade_model.index[k],'position_long'] = False
        elif trade_model.at[trade_model.index[k],'cover_on_open']:
            trade_model.at[trade_model.index[k],'position_short'] = False
        else:
            # If no trade on open, check to see whether we have a breakout either way
            if (breakout_high >= 0) and (not currently_long) and (not currently_short) and (trade_volume > average_volume) and (k < last_index-1) and (not SHORT_ONLY):
                trade_model.at[trade_model.index[k+1],'buy_on_open'] = True
            elif (breakout_low < 0) and (not currently_long) and (not currently_short) and (trade_volume > average_volume) and (k < last_index-1) and (not LONG_ONLY):
                trade_model.at[trade_model.index[k+1],'short_on_open'] = True
            else:
                # If no breakout, check to see whether we need to exit an existing position
                if currently_short and (k < last_index-1):
                    if ((trade_model.at[trade_model.index[k-1],'ma_change'] < 0) and (trade_model.at[trade_model.index[k],'ma_change'] > 0)) or (holding_period == max_holding):
                        trade_model.at[trade_model.index[k+1],'cover_on_open'] = True
                elif currently_long and (k < last_index-1):
                    if ((trade_model.at[trade_model.index[k-1],'ma_change'] > 0) and (trade_model.at[trade_model.index[k],'ma_change'] < 0)) or (holding_period == max_holding):
                        trade_model.at[trade_model.index[k+1],'sell_on_open'] = True
                # if crossover_avg >= 0:
                #     trade_model.at[trade_model.index[k],'close_above_avg'] = True
                #     if (currently_short and (k > 0) and (k < last_index-1) and trade_model.at[trade_model.index[k-1],'close_below_avg']) or ((holding_period == max_holding) and currently_short):
                #         trade_model.at[trade_model.index[k+1],'cover_on_open'] = True
                # else:
                #     trade_model.at[trade_model.index[k],'close_below_avg'] = True
                #     if (currently_long and (k > 0) and (k < last_index-1) and trade_model.at[trade_model.index[k-1],'close_above_avg']) or ((holding_period == max_holding) and currently_long):
                #         trade_model.at[trade_model.index[k+1],'sell_on_open'] = True

            # If no action on a given day, carry over the position status
            if (k > 0) and (not trade_model.at[trade_model.index[k],'buy_on_open']) and (not trade_model.at[trade_model.index[k],'sell_on_open']) and (not trade_model.at[trade_model.index[k],'short_on_open']) and (not trade_model.at[trade_model.index[k],'cover_on_open']):
                trade_model.at[trade_model.index[k],'position_long'] = trade_model.at[trade_model.index[k-1],'position_long']
                trade_model.at[trade_model.index[k],'position_short'] = trade_model.at[trade_model.index[k-1],'position_short']

        # # Exiting the position on the last day of modeling period
        # if k == last_index-1:
        #     if trade_model.at[trade_model.index[k],'position_long']:
        #         trade_model.at[trade_model.index[k+1],'sell_on_open'] = True
        #         trade_model.at[trade_model.index[k+1],'position_long'] = False
        #     elif trade_model.at[trade_model.index[k],'position_short']:
        #         trade_model.at[trade_model.index[k+1],'cover_on_open'] = True
        #         trade_model.at[trade_model.index[k+1],'position_short'] = False

    if verbose_signals: print(trade_model, '\n')
    return trade_model

# %%
# Build the collection of trading models by iterating through the parameters
trading_model_collection = {}
serial_no = 0
for window_size in range(WINDOW_MIN, WINDOW_MAX+1, WINDOW_INCREMENT):
    for vol_average in range(VOL_MA_MIN, VOL_MA_MAX+1, VOL_MA_INCREMENT):
        for hold_period in range(HOLDING_MIN, HOLDING_MAX+1, HOLDING_INCREMENT):
            for fastma_curve in range(FAST_MA_MIN, FAST_MA_MAX+1, MA_INCREMENT):
                for slowma_curve in range(SLOW_MA_MIN, SLOW_MA_MAX+1, MA_INCREMENT):
                    if (slowma_curve - fastma_curve) < MA_GAP: break
                    serial_no += 1
                    model_tag = 'Model_' + str(serial_no).zfill(3) + '_WINDOW_' + str(window_size).zfill(3) + '_FASTMA_' + str(fastma_curve).zfill(3) + '_SLOWMA_' + str(slowma_curve).zfill(3) + '_VOLMA_' + str(vol_average).zfill(3) + '_HOLD_' + str(hold_period).zfill(3)
                    if verbose_signals: print('Processing model:', model_tag)
                    trading_model = populate_signals(window_size, vol_average, hold_period, fastma_curve, slowma_curve)
                    trading_model_collection[model_tag] = trading_model.copy()
print(len(trading_model_collection), 'trading models generated!')
# Out:
# 90 trading models generated!

# %%
# List the entry/exit points for each model
def list_model_entry_exit(trade_model):
    print(trade_model[trade_model['buy_on_open'] | trade_model['sell_on_open'] | trade_model['short_on_open'] | trade_model['cover_on_open']])

# %%
if verbose_models:
    for model_name in trading_model_collection:
        print('List the signal changes and entry/exit points for model:', model_name)
        list_model_entry_exit(trading_model_collection[model_name])
        print()

# %%
def draw_model_graph(trade_model, mdl_name=STOCK_SYMBOL):
    graph_data = trade_model.copy()
    title_string = 'Simple Trend-Following Trading Model for ' + mdl_name
    fig = plt.figure(figsize=(16,9))
    ylabel = STOCK_SYMBOL + ' price in $'
    ax1 = fig.add_subplot(111, ylabel=ylabel, title=title_string)
    graph_data['fast_ma'].plot(ax=ax1, color='r')
    graph_data['slow_ma'].plot(ax=ax1, color='b')
    graph_data['close_price'].plot(ax=ax1, color='g')
    ax1.plot(graph_data.loc[graph_data['buy_on_open']].index, graph_data.close_price[graph_data['buy_on_open']], '^', markersize=7, color='b',label='Buy on Open')
    ax1.plot(graph_data.loc[graph_data['sell_on_open']].index, graph_data.close_price[graph_data['sell_on_open']], 'v', markersize=7, color='b',label='Sell on Open')
    ax1.plot(graph_data.loc[graph_data['short_on_open']].index, graph_data.close_price[graph_data['short_on_open']], '^', markersize=7, color='r',label='Short on Open')
    ax1.plot(graph_data.loc[graph_data['cover_on_open']].index, graph_data.close_price[graph_data['cover_on_open']], 'v', markersize=7, color='r',label='Cover on Open')
    plt.legend(loc='upper left')
    plt.show()

# %%
if verbose_graphs:
    for model_name in trading_model_collection:
        draw_model_graph(trading_model_collection[model_name], model_name)

# %% [markdown]
# ## Task 4 - Back-test Models

# %%
def generate_trading_portfolios(trade_model):
    # Construct a portfolio to track the transactions and returns
    portfolio = pd.DataFrame(index=trade_model.index, columns=['trade_action', 'price_executed', 'qty_transacted', 'cost_basis', 'gain_loss', 'qty_on_hand', 'cash_on_hand', 'position_value', 'total_position', 'accum_return'])
    portfolio['trade_action'] = False
    portfolio.at[portfolio.index[0],'price_executed'] = 0.00
    portfolio.at[portfolio.index[0],'qty_transacted'] = 0
    portfolio.at[portfolio.index[0],'cost_basis'] = 0.00
    portfolio.at[portfolio.index[0],'gain_loss'] = 0.00
    portfolio.at[portfolio.index[0],'qty_on_hand'] = 0
    portfolio.at[portfolio.index[0],'cash_on_hand'] = INITIAL_CAPITAL
    portfolio.at[portfolio.index[0],'position_value'] = 0.00
    portfolio.at[portfolio.index[0],'total_position'] = INITIAL_CAPITAL
    portfolio.at[portfolio.index[0],'accum_return'] = 0.00
    quantity = 1

    # The conditional parameters below determine how the trading strategy will be carried out
    for i in range(1, len(portfolio)):
        price_per_share = trade_model.at[trade_model.index[i],'open_price']
        if trade_model.at[trade_model.index[i],'buy_on_open']:
            # Code block for Buy on Open
            portfolio.at[portfolio.index[i],'trade_action'] = True
            portfolio.at[portfolio.index[i],'price_executed'] = price_per_share
            portfolio.at[portfolio.index[i],'qty_transacted'] = quantity
            recent_cost = price_per_share * -quantity
            portfolio.at[portfolio.index[i],'cost_basis'] = recent_cost
            portfolio.at[portfolio.index[i],'gain_loss'] = 0.00
            portfolio.at[portfolio.index[i],'qty_on_hand'] = portfolio.iloc[i-1]['qty_on_hand'] + quantity
            portfolio.at[portfolio.index[i],'cash_on_hand'] = portfolio.iloc[i-1]['cash_on_hand'] + recent_cost
            if verbose_trade_actions: print('BOUGHT QTY:', quantity, 'on', portfolio.index[i].date(), 'at the price of', price_per_share)
        elif trade_model.at[trade_model.index[i],'sell_on_open']:
            # Code block for Sell on Open
            portfolio.at[portfolio.index[i],'trade_action'] = True
            portfolio.at[portfolio.index[i],'price_executed'] = price_per_share
            portfolio.at[portfolio.index[i],'qty_transacted'] = -quantity
            recent_cost = 0.00
            portfolio.at[portfolio.index[i],'cost_basis'] = recent_cost
            portfolio.at[portfolio.index[i],'gain_loss'] = (price_per_share * quantity) + portfolio.iloc[i-1]['cost_basis']
            portfolio.at[portfolio.index[i],'qty_on_hand'] = portfolio.iloc[i-1]['qty_on_hand'] - quantity
            portfolio.at[portfolio.index[i],'cash_on_hand'] = portfolio.iloc[i-1]['cash_on_hand'] + (price_per_share * quantity)
            if verbose_trade_actions: print('SOLD QTY:', quantity, 'on', portfolio.index[i].date(), 'at the price of', price_per_share)
        elif trade_model.at[trade_model.index[i],'short_on_open']:
            # Code block for Short on Open
            portfolio.at[portfolio.index[i],'trade_action'] = True
            portfolio.at[portfolio.index[i],'price_executed'] = price_per_share
            portfolio.at[portfolio.index[i],'qty_transacted'] = -quantity
            recent_cost = price_per_share * quantity
            portfolio.at[portfolio.index[i],'cost_basis'] = recent_cost
            portfolio.at[portfolio.index[i],'gain_loss'] = 0.00
            portfolio.at[portfolio.index[i],'qty_on_hand'] = portfolio.iloc[i-1]['qty_on_hand'] - quantity
            portfolio.at[portfolio.index[i],'cash_on_hand'] = portfolio.iloc[i-1]['cash_on_hand'] + recent_cost
            if verbose_trade_actions: print('SHORTED QTY:', -quantity, 'on', portfolio.index[i].date(), 'at the price of', trade_model.at[portfolio.index[i],'open_price'])
        elif trade_model.at[trade_model.index[i],'cover_on_open']:
            # Code block for Cover on Open
            portfolio.at[portfolio.index[i],'trade_action'] = True
            portfolio.at[portfolio.index[i],'price_executed'] = price_per_share
            portfolio.at[portfolio.index[i],'qty_transacted'] = quantity
            recent_cost = 0.00
            portfolio.at[portfolio.index[i],'cost_basis'] = recent_cost
            portfolio.at[portfolio.index[i],'gain_loss'] = portfolio.iloc[i-1]['cost_basis'] - (price_per_share * quantity)
            portfolio.at[portfolio.index[i],'qty_on_hand'] = portfolio.iloc[i-1]['qty_on_hand'] + quantity
            portfolio.at[portfolio.index[i],'cash_on_hand'] = portfolio.iloc[i-1]['cash_on_hand'] - (price_per_share * quantity)
            if verbose_trade_actions: print('COVERED QTY:', quantity, 'on', portfolio.index[i].date(), 'at the price of', trade_model.at[portfolio.index[i],'open_price'])
        else:
            # Code block for no trade actions
            portfolio.at[portfolio.index[i],'price_executed'] = 0.00
            portfolio.at[portfolio.index[i],'qty_transacted'] = 0
            portfolio.at[portfolio.index[i],'cost_basis'] = portfolio.iloc[i-1]['cost_basis']
            portfolio.at[portfolio.index[i],'gain_loss'] = 0.00
            portfolio.at[portfolio.index[i],'qty_on_hand'] = portfolio.iloc[i-1]['qty_on_hand']
            portfolio.at[portfolio.index[i],'cash_on_hand'] = portfolio.iloc[i-1]['cash_on_hand']
        portfolio.at[portfolio.index[i],'position_value'] = trade_model.at[trade_model.index[i],'close_price'] * portfolio.at[portfolio.index[i],'qty_on_hand']
        portfolio.at[portfolio.index[i],'total_position'] = portfolio.at[portfolio.index[i],'cash_on_hand'] + portfolio.at[portfolio.index[i],'position_value']
        portfolio.at[portfolio.index[i],'accum_return'] = portfolio.at[portfolio.index[i],'total_position'] - INITIAL_CAPITAL

    if verbose_portfolios: print('\n', portfolio, '\n')
    return portfolio

# %%
def calculate_positions_and_performance(trade_model):
    trade_positions = generate_trading_portfolios(trade_model)
    trade_transactions = trade_positions[trade_positions['trade_action']]
    if verbose_transactions: print(trade_transactions)
    if trade_transactions.at[trade_transactions.index[-1],'trade_action']:
        if trade_transactions.at[trade_transactions.index[-1],'qty_on_hand'] == 0:
            print('The current status of the model is:','Waiting to enter a position since',trade_transactions.index.tolist()[-1].date(),'\n')
        elif trade_transactions.at[trade_transactions.index[-1],'qty_on_hand'] > 0:
            print('The current status of the model is:','Holding a long position since',trade_transactions.index.tolist()[-1].date(),'\n')
        else:
            print('The current status of the model is:','Holding a short position since',trade_transactions.index.tolist()[-1].date(),'\n')
    return trade_positions

# %%
# Convert trading models into positions and calculate profit and loss
# Initialize a dictionary for tracking positions for all models
model_positions_collection={}

for model_name in trading_model_collection:
    print('Processing the positions for model:', model_name)
    model_positions_collection[model_name] = calculate_positions_and_performance(trading_model_collection[model_name])
print(len(model_positions_collection), 'sets of model positions generated.')
# Out:
# Processing the positions for model: Model_001_WINDOW_010_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-09          True          44.49              1          0    -0.864           0       -0.864              0         -0.864       -0.864
# 2018-03-22          True           42.5             -1       42.5         0          -1       41.636        -42.212         -0.576       -0.576
# 2018-05-11          True         47.373              1          0    -4.873           0       -5.737              0         -5.737       -5.737
# 2018-06-18          True          46.97             -1      46.97         0          -1       41.233        -47.185         -5.952       -5.952
# 2018-07-25          True         48.265              1          0    -1.295           0       -7.032              0         -7.032       -7.032
# 2018-07-31          True         47.575             -1     47.575         0          -1       40.543        -47.572         -7.029       -7.029
# 2019-02-13          True         42.847              1          0     4.728           0       -2.304              0         -2.304       -2.304
# 2019-05-13          True         46.928             -1     46.928         0          -1       44.624         -46.43         -1.806       -1.806
# 2019-07-02          True         50.352              1          0    -3.424           0       -5.728              0         -5.728       -5.728
# 2019-08-06          True         49.078             -1     49.078         0          -1        43.35         -49.25           -5.9         -5.9
# 2020-05-01          True         71.563              1          0   -22.485           0      -28.213              0        -28.213      -28.213
# 2020-07-24          True         90.987             -1     90.987         0          -1       62.774        -92.615        -29.841      -29.841
# 2020-11-06          True         118.32              1          0   -27.333           0      -55.546              0        -55.546      -55.546
# 2020-11-24          True         113.91             -1     113.91         0          -1       58.364        -115.17        -56.806      -56.806
# The current status of the model is: Holding a short position since 2020-11-24
#
# Processing the positions for model: Model_002_WINDOW_010_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-12          True         45.072              1          0    -1.446           0       -1.446              0         -1.446       -1.446
# 2018-03-22          True           42.5             -1       42.5         0          -1       41.054        -42.212         -1.158       -1.158
# 2018-05-10          True         46.935              1          0    -4.435           0       -5.881              0         -5.881       -5.881
# 2018-06-18          True          46.97             -1      46.97         0          -1       41.089        -47.185         -6.096       -6.096
# 2019-02-19          True         42.428              1          0     4.542           0       -1.339              0         -1.339       -1.339
# 2019-05-13          True         46.928             -1     46.928         0          -1       45.589         -46.43         -0.841       -0.841
# 2019-07-03          True          50.82              1          0    -3.892           0       -5.231              0         -5.231       -5.231
# 2019-08-06          True         49.078             -1     49.078         0          -1       43.847         -49.25         -5.403       -5.403
# 2020-05-05          True         73.765              1          0   -24.687           0      -29.918              0        -29.918      -29.918
# 2020-07-24          True         90.987             -1     90.987         0          -1       61.069        -92.615        -31.546      -31.546
# 2020-11-27          True         116.57              1          0   -25.583           0      -55.501              0        -55.501      -55.501
# 2021-01-07          True         128.36             -1     128.36         0          -1       72.859        -130.92        -58.061      -58.061
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_003_WINDOW_010_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-12          True         45.072              1          0    -1.446           0       -1.446              0         -1.446       -1.446
# 2018-03-22          True           42.5             -1       42.5         0          -1       41.054        -42.212         -1.158       -1.158
# 2018-05-07          True         46.295              1          0    -3.795           0       -5.241              0         -5.241       -5.241
# 2018-06-18          True          46.97             -1      46.97         0          -1       41.729        -47.185         -5.456       -5.456
# 2019-02-25          True          43.54              1          0      3.43           0       -1.811              0         -1.811       -1.811
# 2019-05-13          True         46.928             -1     46.928         0          -1       45.117         -46.43         -1.313       -1.313
# 2019-07-03          True          50.82              1          0    -3.892           0       -5.703              0         -5.703       -5.703
# 2019-08-06          True         49.078             -1     49.078         0          -1       43.375         -49.25         -5.875       -5.875
# 2020-05-08          True          76.41              1          0   -27.332           0      -33.035              0        -33.035      -33.035
# 2020-07-24          True         90.987             -1     90.987         0          -1       57.952        -92.615        -34.663      -34.663
# 2020-12-02          True         122.02              1          0   -31.033           0      -64.068              0        -64.068      -64.068
# 2021-01-07          True         128.36             -1     128.36         0          -1       64.292        -130.92        -66.628      -66.628
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_004_WINDOW_010_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-12          True         45.072              1          0    -1.446           0       -1.446              0         -1.446       -1.446
# 2018-03-22          True           42.5             -1       42.5         0          -1       41.054        -42.212         -1.158       -1.158
# 2018-05-08          True         46.248              1          0    -3.748           0       -5.194              0         -5.194       -5.194
# 2018-06-18          True          46.97             -1      46.97         0          -1       41.776        -47.185         -5.409       -5.409
# 2019-02-28          True          43.58              1          0      3.39           0       -1.804              0         -1.804       -1.804
# 2019-05-13          True         46.928             -1     46.928         0          -1       45.124         -46.43         -1.306       -1.306
# 2019-07-01          True         50.792              1          0    -3.864           0       -5.668              0         -5.668       -5.668
# 2019-08-06          True         49.078             -1     49.078         0          -1        43.41         -49.25          -5.84        -5.84
# 2020-05-12          True         79.457              1          0   -30.379           0      -36.047              0        -36.047      -36.047
# 2020-07-24          True         90.987             -1     90.987         0          -1        54.94        -92.615        -37.675      -37.675
# 2020-12-01          True         121.01              1          0   -30.023           0       -66.07              0         -66.07       -66.07
# 2021-01-07          True         128.36             -1     128.36         0          -1        62.29        -130.92         -68.63       -68.63
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_005_WINDOW_010_FASTMA_020_SLOWMA_090_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-09          True          44.49              1          0    -0.864           0       -0.864              0         -0.864       -0.864
# 2018-03-22          True           42.5             -1       42.5         0          -1       41.636        -42.212         -0.576       -0.576
# 2018-05-08          True         46.248              1          0    -3.748           0       -4.612              0         -4.612       -4.612
# 2018-06-18          True          46.97             -1      46.97         0          -1       42.358        -47.185         -4.827       -4.827
# 2019-03-12          True             45              1          0      1.97           0       -2.642              0         -2.642       -2.642
# 2019-05-13          True         46.928             -1     46.928         0          -1       44.286         -46.43         -2.144       -2.144
# 2019-06-27          True         50.072              1          0    -3.144           0       -5.786              0         -5.786       -5.786
# 2019-08-06          True         49.078             -1     49.078         0          -1       43.292         -49.25         -5.958       -5.958
# 2020-05-13          True         78.037              1          0   -28.959           0      -34.745              0        -34.745      -34.745
# 2020-07-24          True         90.987             -1     90.987         0          -1       56.242        -92.615        -36.373      -36.373
# The current status of the model is: Holding a short position since 2020-07-24
#
# Processing the positions for model: Model_006_WINDOW_010_FASTMA_020_SLOWMA_100_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-07          True         43.735              1          0    -0.109           0       -0.109              0         -0.109       -0.109
# 2018-03-22          True           42.5             -1       42.5         0          -1       42.391        -42.212          0.179        0.179
# 2018-05-09          True         46.638              1          0    -4.138           0       -4.247              0         -4.247       -4.247
# 2018-06-18          True          46.97             -1      46.97         0          -1       42.723        -47.185         -4.462       -4.462
# 2019-03-18          True          46.45              1          0      0.52           0       -3.727              0         -3.727       -3.727
# 2019-05-13          True         46.928             -1     46.928         0          -1       43.201         -46.43         -3.229       -3.229
# 2019-06-24          True         49.635              1          0    -2.707           0       -6.434              0         -6.434       -6.434
# 2019-08-06          True         49.078             -1     49.078         0          -1       42.644         -49.25         -6.606       -6.606
# 2020-05-13          True         78.037              1          0   -28.959           0      -35.393              0        -35.393      -35.393
# 2020-07-24          True         90.987             -1     90.987         0          -1       55.594        -92.615        -37.021      -37.021
# The current status of the model is: Holding a short position since 2020-07-24
#
# Processing the positions for model: Model_007_WINDOW_010_FASTMA_030_SLOWMA_050_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-21          True          43.76              1          0    -0.134           0       -0.134              0         -0.134       -0.134
# 2018-03-23          True         42.097             -1     42.097         0          -1       41.963        -41.235          0.728        0.728
# 2018-05-15          True         46.695              1          0    -4.598           0       -4.732              0         -4.732       -4.732
# 2018-06-18          True          46.97             -1      46.97         0          -1       42.238        -47.185         -4.947       -4.947
# 2018-08-03          True         51.758              1          0    -4.788           0        -9.52              0          -9.52        -9.52
# 2018-09-18          True         54.447             -1     54.447         0          -1       44.927         -54.56         -9.633       -9.633
# 2019-02-20          True         42.797              1          0     11.65           0         2.13              0           2.13         2.13
# 2019-05-13          True         46.928             -1     46.928         0          -1       49.058         -46.43          2.628        2.628
# 2019-07-12          True         50.612              1          0    -3.684           0       -1.554              0         -1.554       -1.554
# 2019-08-06          True         49.078             -1     49.078         0          -1       47.524         -49.25         -1.726       -1.726
# 2020-05-06          True         75.115              1          0   -26.037           0      -27.591              0        -27.591      -27.591
# 2020-07-24          True         90.987             -1     90.987         0          -1       63.396        -92.615        -29.219      -29.219
# 2020-11-10          True         115.55              1          0   -24.563           0      -52.154              0        -52.154      -52.154
# 2020-11-24          True         113.91             -1     113.91         0          -1       61.756        -115.17        -53.414      -53.414
# The current status of the model is: Holding a short position since 2020-11-24
#
# Processing the positions for model: Model_008_WINDOW_010_FASTMA_030_SLOWMA_060_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-21          True          43.76              1          0    -0.134           0       -0.134              0         -0.134       -0.134
# 2018-03-23          True         42.097             -1     42.097         0          -1       41.963        -41.235          0.728        0.728
# 2018-05-15          True         46.695              1          0    -4.598           0       -4.732              0         -4.732       -4.732
# 2018-06-18          True          46.97             -1      46.97         0          -1       42.238        -47.185         -4.947       -4.947
# 2018-08-02          True         50.145              1          0    -3.175           0       -7.907              0         -7.907       -7.907
# 2018-09-18          True         54.447             -1     54.447         0          -1        46.54         -54.56          -8.02        -8.02
# 2019-02-26          True         43.428              1          0    11.019           0        3.112              0          3.112        3.112
# 2019-05-13          True         46.928             -1     46.928         0          -1        50.04         -46.43           3.61         3.61
# 2019-07-16          True         51.148              1          0     -4.22           0       -1.108              0         -1.108       -1.108
# 2019-08-06          True         49.078             -1     49.078         0          -1        47.97         -49.25          -1.28        -1.28
# 2020-05-12          True         79.457              1          0   -30.379           0      -31.487              0        -31.487      -31.487
# 2020-07-24          True         90.987             -1     90.987         0          -1         59.5        -92.615        -33.115      -33.115
# 2020-11-19          True         117.59              1          0   -26.603           0       -58.09              0         -58.09       -58.09
# 2020-11-24          True         113.91             -1     113.91         0          -1        55.82        -115.17         -59.35       -59.35
# The current status of the model is: Holding a short position since 2020-11-24
#
# Processing the positions for model: Model_009_WINDOW_010_FASTMA_030_SLOWMA_070_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-21          True          43.76              1          0    -0.134           0       -0.134              0         -0.134       -0.134
# 2018-03-23          True         42.097             -1     42.097         0          -1       41.963        -41.235          0.728        0.728
# 2018-05-09          True         46.638              1          0    -4.541           0       -4.675              0         -4.675       -4.675
# 2018-06-18          True          46.97             -1      46.97         0          -1       42.295        -47.185          -4.89        -4.89
# 2019-03-01          True          43.57              1          0       3.4           0       -1.275              0         -1.275       -1.275
# 2019-05-13          True         46.928             -1     46.928         0          -1       45.653         -46.43         -0.777       -0.777
# 2019-07-16          True         51.148              1          0     -4.22           0       -5.495              0         -5.495       -5.495
# 2019-08-06          True         49.078             -1     49.078         0          -1       43.583         -49.25         -5.667       -5.667
# 2020-05-15          True         75.088              1          0    -26.01           0      -31.505              0        -31.505      -31.505
# 2020-07-24          True         90.987             -1     90.987         0          -1       59.482        -92.615        -33.133      -33.133
# 2020-12-07          True         122.31              1          0   -31.323           0      -62.828              0        -62.828      -62.828
# 2021-01-07          True         128.36             -1     128.36         0          -1       65.532        -130.92        -65.388      -65.388
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_010_WINDOW_010_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-21          True          43.76              1          0    -0.134           0       -0.134              0         -0.134       -0.134
# 2018-03-23          True         42.097             -1     42.097         0          -1       41.963        -41.235          0.728        0.728
# 2018-05-10          True         46.935              1          0    -4.838           0       -4.972              0         -4.972       -4.972
# 2018-06-18          True          46.97             -1      46.97         0          -1       41.998        -47.185         -5.187       -5.187
# 2019-03-07          True         43.468              1          0     3.502           0        -1.47              0          -1.47        -1.47
# 2019-05-13          True         46.928             -1     46.928         0          -1       45.458         -46.43         -0.972       -0.972
# 2019-07-15          True         51.023              1          0    -4.095           0       -5.565              0         -5.565       -5.565
# 2019-08-06          True         49.078             -1     49.078         0          -1       43.513         -49.25         -5.737       -5.737
# 2020-05-19          True         78.757              1          0   -29.679           0      -35.244              0        -35.244      -35.244
# 2020-07-24          True         90.987             -1     90.987         0          -1       55.743        -92.615        -36.872      -36.872
# 2020-12-09          True         124.53              1          0   -33.543           0      -68.787              0        -68.787      -68.787
# 2021-01-07          True         128.36             -1     128.36         0          -1       59.573        -130.92        -71.347      -71.347
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_011_WINDOW_010_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-21          True          43.76              1          0    -0.134           0       -0.134              0         -0.134       -0.134
# 2018-03-23          True         42.097             -1     42.097         0          -1       41.963        -41.235          0.728        0.728
# 2018-05-11          True         47.373              1          0    -5.276           0        -5.41              0          -5.41        -5.41
# 2018-06-18          True          46.97             -1      46.97         0          -1        41.56        -47.185         -5.625       -5.625
# 2019-03-14          True         45.975              1          0     0.995           0       -4.415              0         -4.415       -4.415
# 2019-05-13          True         46.928             -1     46.928         0          -1       42.513         -46.43         -3.917       -3.917
# 2019-07-10          True         50.462              1          0    -3.534           0       -7.949              0         -7.949       -7.949
# 2019-08-06          True         49.078             -1     49.078         0          -1       41.129         -49.25         -8.121       -8.121
# 2020-05-21          True         79.665              1          0   -30.587           0      -38.536              0        -38.536      -38.536
# 2020-07-24          True         90.987             -1     90.987         0          -1       52.451        -92.615        -40.164      -40.164
# The current status of the model is: Holding a short position since 2020-07-24
#
# Processing the positions for model: Model_012_WINDOW_010_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-03-16          True         44.663              1          0    -1.037           0       -1.037              0         -1.037       -1.037
# 2018-03-22          True           42.5             -1       42.5         0          -1       41.463        -42.212         -0.749       -0.749
# 2018-05-11          True         47.373              1          0    -4.873           0        -5.91              0          -5.91        -5.91
# 2018-06-18          True          46.97             -1      46.97         0          -1        41.06        -47.185         -6.125       -6.125
# 2019-03-20          True         46.557              1          0     0.413           0       -5.497              0         -5.497       -5.497
# 2019-05-13          True         46.928             -1     46.928         0          -1       41.431         -46.43         -4.999       -4.999
# 2020-05-21          True         79.665              1          0   -32.737           0      -38.234              0        -38.234      -38.234
# 2020-07-24          True         90.987             -1     90.987         0          -1       52.753        -92.615        -39.862      -39.862
# The current status of the model is: Holding a short position since 2020-07-24
#
# Processing the positions for model: Model_013_WINDOW_010_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-04-04          True          41.22              1          0     2.406           0        2.406              0          2.406        2.406
# 2018-04-23          True         41.709             -1     41.709         0          -1       44.115         -41.31          2.805        2.805
# 2018-05-23          True         46.587              1          0    -4.878           0       -2.472              0         -2.472       -2.472
# 2018-06-18          True          46.97             -1      46.97         0          -1       44.498        -47.185         -2.687       -2.687
# 2019-02-26          True         43.428              1          0     3.542           0         1.07              0           1.07         1.07
# 2019-05-13          True         46.928             -1     46.928         0          -1       47.998         -46.43          1.568        1.568
# 2019-07-18          True             51              1          0    -4.072           0       -3.002              0         -3.002       -3.002
# 2019-08-06          True         49.078             -1     49.078         0          -1       46.076         -49.25         -3.174       -3.174
# 2020-05-15          True         75.088              1          0    -26.01           0      -29.012              0        -29.012      -29.012
# 2020-07-24          True         90.987             -1     90.987         0          -1       61.975        -92.615         -30.64       -30.64
# 2020-11-13          True         119.44              1          0   -28.453           0      -57.465              0        -57.465      -57.465
# 2020-11-24          True         113.91             -1     113.91         0          -1       56.445        -115.17        -58.725      -58.725
# 2020-12-22          True         131.61              1          0     -17.7           0      -75.165              0        -75.165      -75.165
# 2021-01-07          True         128.36             -1     128.36         0          -1       53.195        -130.92        -77.725      -77.725
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_014_WINDOW_010_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-04-06          True         42.742              1          0     0.884           0        0.884              0          0.884        0.884
# 2018-04-23          True         41.709             -1     41.709         0          -1       42.593         -41.31          1.283        1.283
# 2018-05-24          True         47.193              1          0    -5.484           0         -4.6              0           -4.6         -4.6
# 2018-06-18          True          46.97             -1      46.97         0          -1        42.37        -47.185         -4.815       -4.815
# 2019-03-05          True         43.985              1          0     2.985           0       -1.615              0         -1.615       -1.615
# 2019-05-13          True         46.928             -1     46.928         0          -1       45.313         -46.43         -1.117       -1.117
# 2019-07-24          True         51.917              1          0    -4.989           0       -6.604              0         -6.604       -6.604
# 2019-08-06          True         49.078             -1     49.078         0          -1       42.474         -49.25         -6.776       -6.776
# 2020-05-19          True         78.757              1          0   -29.679           0      -36.283              0        -36.283      -36.283
# 2020-07-24          True         90.987             -1     90.987         0          -1       54.704        -92.615        -37.911      -37.911
# 2020-11-23          True         117.18              1          0   -26.193           0      -62.476              0        -62.476      -62.476
# 2021-01-07          True         128.36             -1     128.36         0          -1       65.884        -130.92        -65.036      -65.036
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_015_WINDOW_010_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-04-06          True         42.742              1          0     0.884           0        0.884              0          0.884        0.884
# 2018-04-23          True         41.709             -1     41.709         0          -1       42.593         -41.31          1.283        1.283
# 2019-03-08          True          42.58              1          0    -0.871           0        0.013              0          0.013        0.013
# 2019-05-13          True         46.928             -1     46.928         0          -1       46.941         -46.43          0.511        0.511
# 2019-07-26          True          51.87              1          0    -4.942           0       -4.929              0         -4.929       -4.929
# 2019-08-06          True         49.078             -1     49.078         0          -1       44.149         -49.25         -5.101       -5.101
# 2020-05-22          True         78.942              1          0   -29.864           0      -34.793              0        -34.793      -34.793
# 2020-07-24          True         90.987             -1     90.987         0          -1       56.194        -92.615        -36.421      -36.421
# 2020-12-03          True         123.52              1          0   -32.533           0      -67.326              0        -67.326      -67.326
# 2021-01-07          True         128.36             -1     128.36         0          -1       61.034        -130.92        -69.886      -69.886
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_016_WINDOW_010_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-04-09          True          42.47              1          0     1.156           0        1.156              0          1.156        1.156
# 2018-04-23          True         41.709             -1     41.709         0          -1       42.865         -41.31          1.555        1.555
# 2019-03-13          True         45.563              1          0    -3.854           0       -2.698              0         -2.698       -2.698
# 2019-05-13          True         46.928             -1     46.928         0          -1        44.23         -46.43           -2.2         -2.2
# 2019-07-26          True          51.87              1          0    -4.942           0        -7.64              0          -7.64        -7.64
# 2019-08-06          True         49.078             -1     49.078         0          -1       41.438         -49.25         -7.812       -7.812
# 2020-05-28          True         79.192              1          0   -30.114           0      -37.754              0        -37.754      -37.754
# 2020-07-24          True         90.987             -1     90.987         0          -1       53.233        -92.615        -39.382      -39.382
# 2020-12-02          True         122.02              1          0   -31.033           0      -68.787              0        -68.787      -68.787
# 2021-01-07          True         128.36             -1     128.36         0          -1       59.573        -130.92        -71.347      -71.347
# The current status of the model is: Holding a short position since 2021-01-07
#
# Processing the positions for model: Model_017_WINDOW_010_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-04-09          True          42.47              1          0     1.156           0        1.156              0          1.156        1.156
# 2018-04-23          True         41.709             -1     41.709         0          -1       42.865         -41.31          1.555        1.555
# 2019-03-19          True         47.087              1          0    -5.378           0       -4.222              0         -4.222       -4.222
# 2019-05-13          True         46.928             -1     46.928         0          -1       42.706         -46.43         -3.724       -3.724
# 2019-07-25          True         52.222              1          0    -5.294           0       -9.516              0         -9.516       -9.516
# 2019-08-06          True         49.078             -1     49.078         0          -1       39.562         -49.25         -9.688       -9.688
# 2020-06-01          True         79.438              1          0    -30.36           0      -39.876              0        -39.876      -39.876
# 2020-07-24          True         90.987             -1     90.987         0          -1       51.111        -92.615        -41.504      -41.504
# The current status of the model is: Holding a short position since 2020-07-24
#
# Processing the positions for model: Model_018_WINDOW_010_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-25          True         43.626             -1     43.626         0          -1       43.626        -42.778          0.848        0.848
# 2018-04-09          True          42.47              1          0     1.156           0        1.156              0          1.156        1.156
# 2018-04-23          True         41.709             -1     41.709         0          -1       42.865         -41.31          1.555        1.555
# 2019-03-25          True         47.877              1          0    -6.168           0       -5.012              0         -5.012       -5.012
# 2019-05-13          True         46.928             -1     46.928         0          -1       41.916         -46.43         -4.514       -4.514
# 2020-06-02          True         80.186              1          0   -33.258           0       -38.27              0         -38.27       -38.27
# 2020-07-24          True         90.987             -1     90.987         0          -1       52.717        -92.615        -39.898      -39.898
# The current status of the model is: Holding a short position since 2020-07-24
#
# Processing the positions for model: Model_019_WINDOW_020_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-09          True          44.49              1          0    -3.109           0       -3.109              0         -3.109       -3.109
# 2018-03-23          True         42.097             -1     42.097         0          -1       38.988        -41.235         -2.247       -2.247
# 2018-05-11          True         47.373              1          0    -5.276           0       -8.385              0         -8.385       -8.385
# 2018-06-20          True         46.587             -1     46.587         0          -1       38.202        -46.625         -8.423       -8.423
# 2018-07-25          True         48.265              1          0    -1.678           0      -10.063              0        -10.063      -10.063
# 2018-10-11          True          53.63             -1      53.63         0          -1       43.567        -53.612        -10.045      -10.045
# 2019-02-13          True         42.847              1          0    10.783           0         0.72              0           0.72         0.72
# 2019-05-13          True         46.928             -1     46.928         0          -1       47.648         -46.43          1.218        1.218
# 2019-07-02          True         50.352              1          0    -3.424           0       -2.704              0         -2.704       -2.704
# 2019-08-06          True         49.078             -1     49.078         0          -1       46.374         -49.25         -2.876       -2.876
# 2020-05-01          True         71.563              1          0   -22.485           0      -25.189              0        -25.189      -25.189
# 2020-09-21          True         104.54             -1     104.54         0          -1       79.351        -110.08        -30.729      -30.729
# 2020-11-06          True         118.32              1          0    -13.78           0      -38.969              0        -38.969      -38.969
# The current status of the model is: Waiting to enter a position since 2020-11-06
#
# Processing the positions for model: Model_020_WINDOW_020_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-12          True         45.072              1          0    -3.691           0       -3.691              0         -3.691       -3.691
# 2018-03-23          True         42.097             -1     42.097         0          -1       38.406        -41.235         -2.829       -2.829
# 2018-05-10          True         46.935              1          0    -4.838           0       -8.529              0         -8.529       -8.529
# 2018-06-20          True         46.587             -1     46.587         0          -1       38.058        -46.625         -8.567       -8.567
# 2019-02-19          True         42.428              1          0     4.159           0        -4.37              0          -4.37        -4.37
# 2019-05-13          True         46.928             -1     46.928         0          -1       42.558         -46.43         -3.872       -3.872
# 2019-07-03          True          50.82              1          0    -3.892           0       -8.262              0         -8.262       -8.262
# 2019-08-06          True         49.078             -1     49.078         0          -1       40.816         -49.25         -8.434       -8.434
# 2020-05-05          True         73.765              1          0   -24.687           0      -32.949              0        -32.949      -32.949
# 2020-09-21          True         104.54             -1     104.54         0          -1       71.591        -110.08        -38.489      -38.489
# 2020-11-27          True         116.57              1          0    -12.03           0      -44.979              0        -44.979      -44.979
# The current status of the model is: Waiting to enter a position since 2020-11-27
#
# Processing the positions for model: Model_021_WINDOW_020_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-12          True         45.072              1          0    -3.691           0       -3.691              0         -3.691       -3.691
# 2018-03-23          True         42.097             -1     42.097         0          -1       38.406        -41.235         -2.829       -2.829
# 2018-05-07          True         46.295              1          0    -4.198           0       -7.889              0         -7.889       -7.889
# 2018-06-20          True         46.587             -1     46.587         0          -1       38.698        -46.625         -7.927       -7.927
# 2019-02-25          True          43.54              1          0     3.047           0       -4.842              0         -4.842       -4.842
# 2019-05-13          True         46.928             -1     46.928         0          -1       42.086         -46.43         -4.344       -4.344
# 2019-07-03          True          50.82              1          0    -3.892           0       -8.734              0         -8.734       -8.734
# 2019-08-06          True         49.078             -1     49.078         0          -1       40.344         -49.25         -8.906       -8.906
# 2020-05-08          True          76.41              1          0   -27.332           0      -36.066              0        -36.066      -36.066
# 2020-09-21          True         104.54             -1     104.54         0          -1       68.474        -110.08        -41.606      -41.606
# 2020-12-02          True         122.02              1          0    -17.48           0      -53.546              0        -53.546      -53.546
# The current status of the model is: Waiting to enter a position since 2020-12-02
#
# Processing the positions for model: Model_022_WINDOW_020_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-12          True         45.072              1          0    -3.691           0       -3.691              0         -3.691       -3.691
# 2018-03-23          True         42.097             -1     42.097         0          -1       38.406        -41.235         -2.829       -2.829
# 2018-05-08          True         46.248              1          0    -4.151           0       -7.842              0         -7.842       -7.842
# 2018-06-20          True         46.587             -1     46.587         0          -1       38.745        -46.625          -7.88        -7.88
# 2019-02-28          True          43.58              1          0     3.007           0       -4.835              0         -4.835       -4.835
# ...
# 2020-02-28          True         64.315             -1     64.315         0          -1        58.95         -68.34          -9.39        -9.39
# 2020-05-15          True         75.088              1          0   -10.773           0      -16.138              0        -16.138      -16.138
# The current status of the model is: Waiting to enter a position since 2020-05-15
#
# Processing the positions for model: Model_082_WINDOW_050_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-21          True          43.76              1          0    -2.379           0       -2.379              0         -2.379       -2.379
# 2018-04-30          True         40.532             -1     40.532         0          -1       38.153        -41.315         -3.162       -3.162
# 2018-05-10          True         46.935              1          0    -6.403           0       -8.782              0         -8.782       -8.782
# 2018-10-30          True         52.788             -1     52.788         0          -1       44.006        -53.325         -9.319       -9.319
# 2019-03-07          True         43.468              1          0      9.32           0        0.538              0          0.538        0.538
# 2019-05-24          True          45.05             -1      45.05         0          -1       45.588        -44.742          0.846        0.846
# 2019-07-15          True         51.023              1          0    -5.973           0       -5.435              0         -5.435       -5.435
# 2020-02-28          True         64.315             -1     64.315         0          -1        58.88         -68.34          -9.46        -9.46
# 2020-05-19          True         78.757              1          0   -14.442           0      -19.877              0        -19.877      -19.877
# The current status of the model is: Waiting to enter a position since 2020-05-19
#
# Processing the positions for model: Model_083_WINDOW_050_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-21          True          43.76              1          0    -2.379           0       -2.379              0         -2.379       -2.379
# 2018-04-30          True         40.532             -1     40.532         0          -1       38.153        -41.315         -3.162       -3.162
# 2018-05-11          True         47.373              1          0    -6.841           0        -9.22              0          -9.22        -9.22
# 2018-10-30          True         52.788             -1     52.788         0          -1       43.568        -53.325         -9.757       -9.757
# 2019-03-14          True         45.975              1          0     6.813           0       -2.407              0         -2.407       -2.407
# 2019-05-24          True          45.05             -1      45.05         0          -1       42.643        -44.742         -2.099       -2.099
# 2019-07-10          True         50.462              1          0    -5.412           0       -7.819              0         -7.819       -7.819
# 2020-02-28          True         64.315             -1     64.315         0          -1       56.496         -68.34        -11.844      -11.844
# 2020-05-21          True         79.665              1          0    -15.35           0      -23.169              0        -23.169      -23.169
# The current status of the model is: Waiting to enter a position since 2020-05-21
#
# Processing the positions for model: Model_084_WINDOW_050_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-16          True         44.663              1          0    -3.282           0       -3.282              0         -3.282       -3.282
# 2018-04-30          True         40.532             -1     40.532         0          -1        37.25        -41.315         -4.065       -4.065
# 2018-05-11          True         47.373              1          0    -6.841           0      -10.123              0        -10.123      -10.123
# 2018-10-30          True         52.788             -1     52.788         0          -1       42.665        -53.325         -10.66       -10.66
# 2019-03-20          True         46.557              1          0     6.231           0       -3.892              0         -3.892       -3.892
# 2019-05-24          True          45.05             -1      45.05         0          -1       41.158        -44.742         -3.584       -3.584
# 2020-05-21          True         79.665              1          0   -34.615           0      -38.507              0        -38.507      -38.507
# The current status of the model is: Waiting to enter a position since 2020-05-21
#
# Processing the positions for model: Model_085_WINDOW_050_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-04-04          True          41.22              1          0     0.161           0        0.161              0          0.161        0.161
# 2018-04-30          True         40.532             -1     40.532         0          -1       40.693        -41.315         -0.622       -0.622
# 2018-05-23          True         46.587              1          0    -6.055           0       -5.894              0         -5.894       -5.894
# 2018-10-30          True         52.788             -1     52.788         0          -1       46.894        -53.325         -6.431       -6.431
# 2019-02-26          True         43.428              1          0      9.36           0        3.466              0          3.466        3.466
# 2019-05-24          True          45.05             -1      45.05         0          -1       48.516        -44.742          3.774        3.774
# 2019-07-18          True             51              1          0     -5.95           0       -2.484              0         -2.484       -2.484
# 2020-02-28          True         64.315             -1     64.315         0          -1       61.831         -68.34         -6.509       -6.509
# 2020-05-15          True         75.088              1          0   -10.773           0      -13.257              0        -13.257      -13.257
# The current status of the model is: Waiting to enter a position since 2020-05-15
#
# Processing the positions for model: Model_086_WINDOW_050_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-04-06          True         42.742              1          0    -1.361           0       -1.361              0         -1.361       -1.361
# 2018-04-30          True         40.532             -1     40.532         0          -1       39.171        -41.315         -2.144       -2.144
# 2018-05-24          True         47.193              1          0    -6.661           0       -8.022              0         -8.022       -8.022
# 2018-10-30          True         52.788             -1     52.788         0          -1       44.766        -53.325         -8.559       -8.559
# 2019-03-05          True         43.985              1          0     8.803           0        0.781              0          0.781        0.781
# 2019-05-24          True          45.05             -1      45.05         0          -1       45.831        -44.742          1.089        1.089
# 2019-07-24          True         51.917              1          0    -6.867           0       -6.086              0         -6.086       -6.086
# 2020-02-28          True         64.315             -1     64.315         0          -1       58.229         -68.34        -10.111      -10.111
# 2020-05-19          True         78.757              1          0   -14.442           0      -20.528              0        -20.528      -20.528
# The current status of the model is: Waiting to enter a position since 2020-05-19
#
# Processing the positions for model: Model_087_WINDOW_050_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-04-06          True         42.742              1          0    -1.361           0       -1.361              0         -1.361       -1.361
# 2018-04-30          True         40.532             -1     40.532         0          -1       39.171        -41.315         -2.144       -2.144
# 2019-03-08          True          42.58              1          0    -2.048           0       -3.409              0         -3.409       -3.409
# 2019-05-24          True          45.05             -1      45.05         0          -1       41.641        -44.742         -3.101       -3.101
# 2019-07-26          True          51.87              1          0     -6.82           0      -10.229              0        -10.229      -10.229
# 2020-02-28          True         64.315             -1     64.315         0          -1       54.086         -68.34        -14.254      -14.254
# 2020-05-22          True         78.942              1          0   -14.627           0      -24.856              0        -24.856      -24.856
# The current status of the model is: Waiting to enter a position since 2020-05-22
#
# Processing the positions for model: Model_088_WINDOW_050_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-04-09          True          42.47              1          0    -1.089           0       -1.089              0         -1.089       -1.089
# 2018-04-30          True         40.532             -1     40.532         0          -1       39.443        -41.315         -1.872       -1.872
# 2019-03-13          True         45.563              1          0    -5.031           0        -6.12              0          -6.12        -6.12
# 2019-05-24          True          45.05             -1      45.05         0          -1        38.93        -44.742         -5.812       -5.812
# 2019-07-26          True          51.87              1          0     -6.82           0       -12.94              0         -12.94       -12.94
# 2020-02-28          True         64.315             -1     64.315         0          -1       51.375         -68.34        -16.965      -16.965
# 2020-05-28          True         79.192              1          0   -14.877           0      -27.817              0        -27.817      -27.817
# The current status of the model is: Waiting to enter a position since 2020-05-28
#
# Processing the positions for model: Model_089_WINDOW_050_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-04-09          True          42.47              1          0    -1.089           0       -1.089              0         -1.089       -1.089
# 2018-04-30          True         40.532             -1     40.532         0          -1       39.443        -41.315         -1.872       -1.872
# 2019-03-19          True         47.087              1          0    -6.555           0       -7.644              0         -7.644       -7.644
# 2019-05-24          True          45.05             -1      45.05         0          -1       37.406        -44.742         -7.336       -7.336
# 2019-07-25          True         52.222              1          0    -7.172           0      -14.816              0        -14.816      -14.816
# 2020-02-28          True         64.315             -1     64.315         0          -1       49.499         -68.34        -18.841      -18.841
# 2020-06-01          True         79.438              1          0   -15.123           0      -29.939              0        -29.939      -29.939
# The current status of the model is: Waiting to enter a position since 2020-06-01
#
# Processing the positions for model: Model_090_WINDOW_050_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-04-09          True          42.47              1          0    -1.089           0       -1.089              0         -1.089       -1.089
# 2018-04-30          True         40.532             -1     40.532         0          -1       39.443        -41.315         -1.872       -1.872
# 2019-03-25          True         47.877              1          0    -7.345           0       -8.434              0         -8.434       -8.434
# 2019-05-24          True          45.05             -1      45.05         0          -1       36.616        -44.742         -8.126       -8.126
# 2020-06-02          True         80.186              1          0   -35.136           0       -43.57              0         -43.57       -43.57
# The current status of the model is: Waiting to enter a position since 2020-06-02
#
# 90 sets of model positions generated.

# %%
# Initialize a dataframe for storing the model's profit and loss
model_performance_summary = pd.DataFrame(columns=['Model_name','Return_value','Return_percentage'])
for model_name in model_positions_collection:
    if verbose_positions: print('Processing positions for model:', model_name)
    if verbose_positions: print('Accumulated profit/loss for one share of stock with initial capital of $%.0f at the end of modeling period: $%.2f' % (INITIAL_CAPITAL, model_positions_collection[model_name].accum_return[-1]))
    if INITIAL_CAPITAL != 0:
        return_percentage = model_positions_collection[model_name].accum_return[-1] / INITIAL_CAPITAL * 100
        if verbose_positions: print('Accumulated return percentage based on the initial capital investment: %.2f%%' % return_percentage)
    else:
        return_percentage = None
    if verbose_positions: print()
    model_performance_summary = model_performance_summary.append({'Model_name': model_name, 'Return_value': model_positions_collection[model_name].accum_return[-1], 'Return_percentage': return_percentage}, ignore_index=True)
    model_performance_summary.sort_values(by=['Return_value'], inplace=True, ascending=False)

print(len(model_performance_summary), 'profit/loss summaries generated.\n')
print('The top ten model\'s performance summary:')
print(model_performance_summary.head(10))
# Out:
# Processing positions for model: Model_001_WINDOW_010_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-71.51
#
# Processing positions for model: Model_002_WINDOW_010_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-57.01
#
# Processing positions for model: Model_003_WINDOW_010_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-65.58
#
# Processing positions for model: Model_004_WINDOW_010_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-67.58
#
# Processing positions for model: Model_005_WINDOW_010_FASTMA_020_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-73.63
#
# Processing positions for model: Model_006_WINDOW_010_FASTMA_020_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-74.28
#
# Processing positions for model: Model_007_WINDOW_010_FASTMA_030_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-68.11
#
# Processing positions for model: Model_008_WINDOW_010_FASTMA_030_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-74.05
#
# Processing positions for model: Model_009_WINDOW_010_FASTMA_030_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-64.34
#
# Processing positions for model: Model_010_WINDOW_010_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-70.30
#
# Processing positions for model: Model_011_WINDOW_010_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-77.42
#
# Processing positions for model: Model_012_WINDOW_010_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-77.12
#
# Processing positions for model: Model_013_WINDOW_010_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-76.68
#
# Processing positions for model: Model_014_WINDOW_010_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-63.99
#
# Processing positions for model: Model_015_WINDOW_010_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-68.84
#
# Processing positions for model: Model_016_WINDOW_010_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-70.30
#
# Processing positions for model: Model_017_WINDOW_010_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-78.76
#
# Processing positions for model: Model_018_WINDOW_010_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-77.15
#
# Processing positions for model: Model_019_WINDOW_020_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-38.97
#
# Processing positions for model: Model_020_WINDOW_020_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-44.98
#
# Processing positions for model: Model_021_WINDOW_020_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-53.55
#
# Processing positions for model: Model_022_WINDOW_020_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-55.55
#
# Processing positions for model: Model_023_WINDOW_020_FASTMA_020_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-63.11
#
# Processing positions for model: Model_024_WINDOW_020_FASTMA_020_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-63.75
#
# Processing positions for model: Model_025_WINDOW_020_FASTMA_030_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-42.05
#
# Processing positions for model: Model_026_WINDOW_020_FASTMA_030_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-47.98
#
# Processing positions for model: Model_027_WINDOW_020_FASTMA_030_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-51.90
#
# Processing positions for model: Model_028_WINDOW_020_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-57.86
#
# Processing positions for model: Model_029_WINDOW_020_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-66.49
#
# Processing positions for model: Model_030_WINDOW_020_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-66.59
#
# Processing positions for model: Model_031_WINDOW_020_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-47.59
#
# Processing positions for model: Model_032_WINDOW_020_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-52.60
#
# Processing positions for model: Model_033_WINDOW_020_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-57.07
#
# Processing positions for model: Model_034_WINDOW_020_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-58.53
#
# Processing positions for model: Model_035_WINDOW_020_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-68.50
#
# Processing positions for model: Model_036_WINDOW_020_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-66.90
#
# Processing positions for model: Model_037_WINDOW_030_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-41.47
#
# Processing positions for model: Model_038_WINDOW_030_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-47.48
#
# Processing positions for model: Model_039_WINDOW_030_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-56.05
#
# Processing positions for model: Model_040_WINDOW_030_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-58.05
#
# Processing positions for model: Model_041_WINDOW_030_FASTMA_020_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-65.61
#
# Processing positions for model: Model_042_WINDOW_030_FASTMA_020_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-66.26
#
# Processing positions for model: Model_043_WINDOW_030_FASTMA_030_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-44.55
#
# Processing positions for model: Model_044_WINDOW_030_FASTMA_030_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-50.49
#
# Processing positions for model: Model_045_WINDOW_030_FASTMA_030_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-54.41
#
# Processing positions for model: Model_046_WINDOW_030_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-60.37
#
# Processing positions for model: Model_047_WINDOW_030_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-69.00
#
# Processing positions for model: Model_048_WINDOW_030_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-69.10
#
# Processing positions for model: Model_049_WINDOW_030_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-48.66
#
# Processing positions for model: Model_050_WINDOW_030_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-53.67
#
# Processing positions for model: Model_051_WINDOW_030_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-57.40
#
# Processing positions for model: Model_052_WINDOW_030_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-58.86
#
# Processing positions for model: Model_053_WINDOW_030_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-68.83
#
# Processing positions for model: Model_054_WINDOW_030_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-67.23
#
# Processing positions for model: Model_055_WINDOW_040_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-3.57
#
# Processing positions for model: Model_056_WINDOW_040_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-5.96
#
# Processing positions for model: Model_057_WINDOW_040_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-9.08
#
# Processing positions for model: Model_058_WINDOW_040_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-12.09
#
# Processing positions for model: Model_059_WINDOW_040_FASTMA_020_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-10.79
#
# Processing positions for model: Model_060_WINDOW_040_FASTMA_020_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-11.44
#
# Processing positions for model: Model_061_WINDOW_040_FASTMA_030_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-5.92
#
# Processing positions for model: Model_062_WINDOW_040_FASTMA_030_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-11.43
#
# Processing positions for model: Model_063_WINDOW_040_FASTMA_030_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-7.15
#
# Processing positions for model: Model_064_WINDOW_040_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-10.89
#
# Processing positions for model: Model_065_WINDOW_040_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-14.18
#
# Processing positions for model: Model_066_WINDOW_040_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-36.83
#
# Processing positions for model: Model_067_WINDOW_040_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-4.26
#
# Processing positions for model: Model_068_WINDOW_040_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-11.54
#
# Processing positions for model: Model_069_WINDOW_040_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-15.86
#
# Processing positions for model: Model_070_WINDOW_040_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-18.82
#
# Processing positions for model: Model_071_WINDOW_040_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-20.95
#
# Processing positions for model: Model_072_WINDOW_040_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-41.90
#
# Processing positions for model: Model_073_WINDOW_050_FASTMA_020_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-12.56
#
# Processing positions for model: Model_074_WINDOW_050_FASTMA_020_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-14.95
#
# Processing positions for model: Model_075_WINDOW_050_FASTMA_020_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-18.07
#
# Processing positions for model: Model_076_WINDOW_050_FASTMA_020_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-21.08
#
# Processing positions for model: Model_077_WINDOW_050_FASTMA_020_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-19.78
#
# Processing positions for model: Model_078_WINDOW_050_FASTMA_020_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-20.43
#
# Processing positions for model: Model_079_WINDOW_050_FASTMA_030_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-14.91
#
# Processing positions for model: Model_080_WINDOW_050_FASTMA_030_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-20.42
#
# Processing positions for model: Model_081_WINDOW_050_FASTMA_030_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-16.14
#
# Processing positions for model: Model_082_WINDOW_050_FASTMA_030_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-19.88
#
# Processing positions for model: Model_083_WINDOW_050_FASTMA_030_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-23.17
#
# Processing positions for model: Model_084_WINDOW_050_FASTMA_030_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-38.51
#
# Processing positions for model: Model_085_WINDOW_050_FASTMA_040_SLOWMA_050_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-13.26
#
# Processing positions for model: Model_086_WINDOW_050_FASTMA_040_SLOWMA_060_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-20.53
#
# Processing positions for model: Model_087_WINDOW_050_FASTMA_040_SLOWMA_070_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-24.86
#
# Processing positions for model: Model_088_WINDOW_050_FASTMA_040_SLOWMA_080_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-27.82
#
# Processing positions for model: Model_089_WINDOW_050_FASTMA_040_SLOWMA_090_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-29.94
#
# Processing positions for model: Model_090_WINDOW_050_FASTMA_040_SLOWMA_100_VOLMA_010_HOLD_999
# Accumulated profit/loss for one share of stock with initial capital of $0 at the end of modeling period: $-43.57
#
# 90 profit/loss summaries generated.
#
# The top ten model's performance summary:
#                                           Model_name  Return_value Return_percentage
# 0  Model_055_WINDOW_040_FASTMA_020_SLOWMA_050_VOL...        -3.567              None
# 1  Model_067_WINDOW_040_FASTMA_040_SLOWMA_050_VOL...        -4.265              None
# 2  Model_061_WINDOW_040_FASTMA_030_SLOWMA_050_VOL...        -5.921              None
# 3  Model_056_WINDOW_040_FASTMA_020_SLOWMA_060_VOL...        -5.962              None
# 4  Model_063_WINDOW_040_FASTMA_030_SLOWMA_070_VOL...        -7.146              None
# 5  Model_057_WINDOW_040_FASTMA_020_SLOWMA_070_VOL...        -9.079              None
# 6  Model_059_WINDOW_040_FASTMA_020_SLOWMA_090_VOL...       -10.789              None
# 7  Model_064_WINDOW_040_FASTMA_030_SLOWMA_080_VOL...       -10.885              None
# 8  Model_062_WINDOW_040_FASTMA_030_SLOWMA_060_VOL...       -11.430              None
# 9  Model_060_WINDOW_040_FASTMA_020_SLOWMA_100_VOL...       -11.437              None

# %% [markdown]
# ## Task 5 - Evaluate Strategy Performance

# %%
# Calculate the stock's performance for a buy-and-hold model
top_model_name = model_performance_summary.loc[0]['Model_name']
top_trading_model = trading_model_collection[top_model_name]
print('The entry point for the buy-and-hold model: $%.2f on %s' % (top_trading_model.iloc[0]['open_price'], top_trading_model.index[0].date()))
print('The exit point for the buy-and-hold model: $%.2f on %s' % (top_trading_model.iloc[-1]['open_price'], top_trading_model.index[-1].date()))
print('The performance of the buy-and-hold model: $%.2f' %(top_trading_model.iloc[-1]['open_price'] - top_trading_model.iloc[0]['open_price']))
print('The performance of the top trading model: $%.2f' %(model_performance_summary.iloc[0]['Return_value']))
# Out:
# The entry point for the buy-and-hold model: $42.54 on 2018-01-02
# The exit point for the buy-and-hold model: $130.24 on 2021-02-19
# The performance of the buy-and-hold model: $87.70
# The performance of the top trading model: $-3.57

# %%
top_model_positions = model_positions_collection[top_model_name]
print(top_model_positions[top_model_positions['trade_action'] != 0])
# Out:
#             trade_action price_executed qty_transacted cost_basis gain_loss qty_on_hand cash_on_hand position_value total_position accum_return
# date
# 2018-01-30          True         41.381             -1     41.381         0          -1       41.381        -41.742         -0.361       -0.361
# 2018-03-09          True          44.49              1          0    -3.109           0       -3.109              0         -3.109       -3.109
# 2018-04-25          True         40.655             -1     40.655         0          -1       37.546        -40.913         -3.367       -3.367
# 2018-05-11          True         47.373              1          0    -6.718           0       -9.827              0         -9.827       -9.827
# 2018-10-30          True         52.788             -1     52.788         0          -1       42.961        -53.325        -10.364      -10.364
# 2019-02-13          True         42.847              1          0     9.941           0        0.114              0          0.114        0.114
# 2019-05-14          True         46.602             -1     46.602         0          -1       46.716        -47.165         -0.449       -0.449
# 2019-07-02          True         50.352              1          0     -3.75           0       -3.636              0         -3.636       -3.636
# 2020-02-26          True         71.632             -1     71.632         0          -1       67.996        -73.162         -5.166       -5.166
# 2020-05-01          True         71.563              1          0     0.069           0       -3.567              0         -3.567       -3.567

# %%
draw_model_graph(trading_model_collection[top_model_name], top_model_name)

# %%
print ('Total time for the script:',(datetime.now() - startTimeScript))
# Out:
# Total time for the script: 0:04:48.451151
